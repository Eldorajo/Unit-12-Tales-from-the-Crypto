# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\josep\AppData\Roaming\nltk_data...

# %%
# Read your api key environment variable
# YOUR CODE HERE!

from newsapi import NewsApiClient
load_dotenv()
api_key = os.getenv("NEWSAPI_KEY")

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_news = newsapi.get_everything(
    q="Bitcoin",
    language="en",
    page_size = 100,
    sort_by = "relevancy"
)

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_news = newsapi.get_everything(
    q="Ethereum",
    language="en",
    page_size = 100,
    sort_by = "relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
bitcoin_sentiments = []

for article in btc_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head(10)
# Out:
#          date                                               text  compound  \
# 0  2021-05-12  Just weeks after Tesla started accepting Bitco...    0.3818
# 1  2021-05-07  Shares of Square are up more than 6% today aft...    0.2960
# 2  2021-04-27  Tesla’s relationship with bitcoin is not a dal...    0.0000
# 3  2021-05-12  Image: Tesla\r\n\n \n\n Tesla has stopped acce...    0.4939
# 4  2021-04-23  Cryptocurrency prices continued to tumble Frid...    0.0000
# 5  2021-05-11  Mark Zuckerberg posted a picture of his two, f...    0.8455
# 6  2021-05-19  Illustration by Alex Castro / The Verge\r\n\n ...    0.0000
# 7  2021-05-17  Last week, whenElon Musk tweeted that he had s...    0.4754
# 8  2021-05-12  Tesla CEO Elon Musk has changed his stance on ...    0.3818
# 9  2021-04-27  image copyrightGetty Images\r\nimage captionEl...    0.7003
#
#    positive  negative  neutral
# 0     0.071      0.00    0.929
# 1     0.058      0.00    0.942
# 2     0.000      0.00    1.000
# 3     0.134      0.05    0.816
# 4     0.000      0.00    1.000
# 5     0.217      0.00    0.783
# 6     0.000      0.00    1.000
# 7     0.075      0.00    0.925
# 8     0.071      0.00    0.929
# 9     0.167      0.00    0.833

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_sentiments = []

for article in eth_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head(10)
# Out:
#          date                                               text  compound  \
# 0  2021-05-12  Vitalik Buterin, the creator of Ethereum, on W...    0.2263
# 1  2021-05-04  Their investors call them disruptive innovator...   -0.4019
# 2  2021-05-15  Solana isn’t known yet outside of the crypto c...    0.4019
# 3  2021-05-01  New York (CNN Business)Bitcoin prices continue...    0.0000
# 4  2021-05-03  The creators behind CryptoPunks, one of the mo...    0.4754
# 5  2021-05-19  Bitcoin, Ethereum and a host of Altcoins suffe...   -0.2023
# 6  2021-05-03  By Reuters Staff\r\nFILE PHOTO: A representati...    0.0000
# 7  2021-05-03  A representation of virtual currency Ethereum ...    0.0000
# 8  2021-05-07  It took a while to get here, but Dfinity is fi...    0.0000
# 9  2021-05-03  This story originally appeared on StockMarketU...    0.0000
#
#    positive  negative  neutral
# 0     0.060     0.000    0.940
# 1     0.072     0.150    0.778
# 2     0.083     0.000    0.917
# 3     0.000     0.000    1.000
# 4     0.091     0.000    0.909
# 5     0.066     0.087    0.847
# 6     0.000     0.000    1.000
# 7     0.000     0.000    1.000
# 8     0.000     0.000    1.000
# 9     0.000     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.069450    0.055760    0.039110    0.905160
# std      0.401582    0.068634    0.053804    0.083404
# min     -0.762700    0.000000    0.000000    0.677000
# 25%     -0.058450    0.000000    0.000000    0.846250
# 50%      0.000000    0.019500    0.000000    0.912500
# 75%      0.381800    0.081750    0.070250    1.000000
# max      0.845500    0.275000    0.219000    1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.047518    0.047390    0.036480    0.916120
# std      0.339195    0.055558    0.060473    0.081325
# min     -0.918600    0.000000    0.000000    0.694000
# 25%     -0.083575    0.000000    0.000000    0.859500
# 50%      0.000000    0.046000    0.000000    0.929500
# 75%      0.238025    0.077250    0.067250    1.000000
# max      0.822500    0.256000    0.289000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin @ 0.0557600
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin @0.8455000
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin @ 0.2750000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
# YOUR CODE HERE!
sw =set(stopwords.words('english'))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw_addons = {'much', 'wow', 'week', 'libra', 'musk', 'facebook', 'diem', '2017', 'char', 'ha'}

# %%
# Remove the punctuation from text
# Create a tokenized list of the words
# Lemmatize words into root words
# Convert the words to lowercase
# Remove the stop words
''' 
The assignment asks for items out of order
'''
# Out:
# ' \nThe assignment asks for items out of order\n'

# %%
# applied in the correct order to append swords, remove stopwords, fix case, and tokenize
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    sw = set(stopwords.words('english'))
    # Convert the words to lowercase
    regex = re.compile("[^a-zA-Z ]")
    # Remove the punctuation
    re_clean = regex.sub('', text)
    # Remove the stop words
    words = word_tokenize(re_clean)
    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc_df['tokens'] = btc_df['text'].apply(tokenizer)
btc_df.head(10)
# Out:
#          date                                               text  compound  \
# 0  2021-05-12  Just weeks after Tesla started accepting Bitco...    0.3818
# 1  2021-05-07  Shares of Square are up more than 6% today aft...    0.2960
# 2  2021-04-27  Tesla’s relationship with bitcoin is not a dal...    0.0000
# 3  2021-05-12  Image: Tesla\r\n\n \n\n Tesla has stopped acce...    0.4939
# 4  2021-04-23  Cryptocurrency prices continued to tumble Frid...    0.0000
# 5  2021-05-11  Mark Zuckerberg posted a picture of his two, f...    0.8455
# 6  2021-05-19  Illustration by Alex Castro / The Verge\r\n\n ...    0.0000
# 7  2021-05-17  Last week, whenElon Musk tweeted that he had s...    0.4754
# 8  2021-05-12  Tesla CEO Elon Musk has changed his stance on ...    0.3818
# 9  2021-04-27  image copyrightGetty Images\r\nimage captionEl...    0.7003
#
#    positive  negative  neutral  \
# 0     0.071      0.00    0.929
# 1     0.058      0.00    0.942
# 2     0.000      0.00    1.000
# 3     0.134      0.05    0.816
# 4     0.000      0.00    1.000
# 5     0.217      0.00    0.783
# 6     0.000      0.00    1.000
# 7     0.075      0.00    0.925
# 8     0.071      0.00    0.929
# 9     0.167      0.00    0.833
#
#                                               tokens
# 0  [tesla, started, accepting, bitcoin, currency,...
# 1  [shares, square, today, american, fintech, com...
# 2  [teslas, relationship, bitcoin, dalliance, acc...
# 3  [image, tesla, tesla, stopped, accepting, bitc...
# 4  [cryptocurrency, price, continued, tumble, fri...
# 5  [mark, zuckerberg, posted, picture, two, frank...
# 6  [illustration, alex, castro, verge, cryptocurr...
# 7  [last, whenelon, tweeted, spoken, team, doge, ...
# 8  [tesla, ceo, elon, changed, stance, cryptocurr...
# 9  [image, copyrightgetty, imagesimage, captionel...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_df['tokens'] = eth_df['text'].apply(tokenizer)
eth_df.head(10)
# Out:
#          date                                               text  compound  \
# 0  2021-05-12  Vitalik Buterin, the creator of Ethereum, on W...    0.2263
# 1  2021-05-04  Their investors call them disruptive innovator...   -0.4019
# 2  2021-05-15  Solana isn’t known yet outside of the crypto c...    0.4019
# 3  2021-05-01  New York (CNN Business)Bitcoin prices continue...    0.0000
# 4  2021-05-03  The creators behind CryptoPunks, one of the mo...    0.4754
# 5  2021-05-19  Bitcoin, Ethereum and a host of Altcoins suffe...   -0.2023
# 6  2021-05-03  By Reuters Staff\r\nFILE PHOTO: A representati...    0.0000
# 7  2021-05-03  A representation of virtual currency Ethereum ...    0.0000
# 8  2021-05-07  It took a while to get here, but Dfinity is fi...    0.0000
# 9  2021-05-03  This story originally appeared on StockMarketU...    0.0000
#
#    positive  negative  neutral  \
# 0     0.060     0.000    0.940
# 1     0.072     0.150    0.778
# 2     0.083     0.000    0.917
# 3     0.000     0.000    1.000
# 4     0.091     0.000    0.909
# 5     0.066     0.087    0.847
# 6     0.000     0.000    1.000
# 7     0.000     0.000    1.000
# 8     0.000     0.000    1.000
# 9     0.000     0.000    1.000
#
#                                               tokens
# 0  [vitalik, buterin, creator, ethereum, wednesda...
# 1  [investor, call, disruptive, innovator, detrac...
# 2  [solana, isnt, known, yet, outside, crypto, co...
# 3  [new, york, cnn, businessbitcoin, price, conti...
# 4  [creator, behind, cryptopunks, one, popular, n...
# 5  [bitcoin, ethereum, host, altcoins, suffered, ...
# 6  [reuters, stafffile, photo, representation, vi...
# 7  [representation, virtual, currency, ethereum, ...
# 8  [took, get, dfinity, finally, launchingin, jul...
# 9  [story, originally, appeared, stockmarketus, s...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens
btc_t = get_token(btc_df)

def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

big_btc = bigram_counter(btc_t, 2)
big_btc
# Out:
# {('tesla', 'started'): 1,
#  ('started', 'accepting'): 1,
#  ('accepting', 'bitcoin'): 6,
#  ('bitcoin', 'currency'): 1,
#  ('currency', 'car'): 1,
#  ('car', 'elon'): 1,
#  ('elon', 'revealed'): 1,
#  ('revealed', 'tweet'): 1,
#  ('tweet', 'suspend'): 1,
#  ('suspend', 'effort'): 1,
#  ('effort', 'according'): 1,
#  ('according', 'release'): 1,
#  ('release', 'tesla'): 1,
#  ('tesla', 'doe'): 1,
#  ('doe', 'appear'): 1,
#  ('appear', 'funct'): 1,
#  ('funct', 'shares'): 1,
#  ('shares', 'square'): 1,
#  ('square', 'today'): 1,
#  ('today', 'american'): 1,
#  ('american', 'fintech'): 1,
#  ('fintech', 'company'): 2,
#  ('company', 'reported'): 1,
#  ('reported', 'staggering'): 1,
#  ('staggering', 'billion'): 1,
#  ('billion', 'revenue'): 1,
#  ('revenue', 'q'): 1,
#  ('q', 'earnings'): 1,
#  ('earnings', 'report'): 1,
#  ('report', 'far'): 1,
#  ('far', 'ahead'): 1,
#  ('ahead', 'expected'): 1,
#  ('expected', 'tally'): 1,
#  ('tally', 'bi'): 1,
#  ('bi', 'teslas'): 1,
#  ('teslas', 'relationship'): 1,
#  ('relationship', 'bitcoin'): 1,
#  ('bitcoin', 'dalliance'): 1,
#  ('dalliance', 'according'): 1,
#  ('according', 'comment'): 1,
#  ('comment', 'made'): 1,
#  ('made', 'company'): 1,
#  ('company', 'cfo'): 1,
#  ('cfo', 'dubbed'): 1,
#  ('dubbed', 'master'): 1,
#  ('master', 'coin'): 1,
#  ('coin', 'zach'): 1,
#  ('zach', 'kirkhorn'): 1,
#  ('kirkhorn', 'earnings'): 1,
#  ('earnings', 'call'): 1,
#  ('call', 'monday'): 1,
#  ('monday', 'instead'): 1,
#  ('instead', 'compan'): 1,
#  ('compan', 'image'): 1,
#  ('image', 'tesla'): 1,
#  ('tesla', 'tesla'): 1,
#  ('tesla', 'stopped'): 1,
#  ('stopped', 'accepting'): 2,
#  ('bitcoin', 'payment'): 2,
#  ('payment', 'car'): 1,
#  ('car', 'concern'): 1,
#  ('concern', 'contribute'): 1,
#  ('contribute', 'greater'): 1,
#  ('greater', 'consumption'): 1,
#  ('consumption', 'fossil'): 1,
#  ('fossil', 'fuel'): 3,
#  ('fuel', 'according'): 1,
#  ('according', 'statement'): 1,
#  ('statement', 'ceo'): 1,
#  ('ceo', 'elon'): 5,
#  ('elon', 'tw'): 1,
#  ('tw', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'price'): 2,
#  ('price', 'continued'): 2,
#  ('continued', 'tumble'): 1,
#  ('tumble', 'friday'): 1,
#  ('friday', 'bitcoin'): 1,
#  ('bitcoin', 'leading'): 1,
#  ('leading', 'charge'): 1,
#  ('charge', 'price'): 1,
#  ('price', 'internet'): 1,
#  ('internet', 'currency'): 1,
#  ('currency', 'dipping'): 1,
#  ('dipping', 'first'): 1,
#  ('first', 'time'): 1,
#  ('time', 'since'): 1,
#  ('since', 'early'): 1,
#  ('early', 'marchbitcoin'): 1,
#  ('marchbitcoin', 'ro'): 1,
#  ('ro', 'mark'): 1,
#  ('mark', 'zuckerberg'): 1,
#  ('zuckerberg', 'posted'): 1,
#  ('posted', 'picture'): 1,
#  ('picture', 'two'): 1,
#  ('two', 'frankly'): 1,
#  ('frankly', 'adorable'): 1,
#  ('adorable', 'goat'): 1,
#  ('goat', 'noting'): 1,
#  ('noting', 'name'): 1,
#  ('name', 'max'): 1,
#  ('max', 'bitcoinand'): 1,
#  ('bitcoinand', 'say'): 1,
#  ('say', 'ok'): 1,
#  ('ok', 'thenheres'): 1,
#  ('thenheres', 'post'): 1,
#  ('post', 'questionlook'): 1,
#  ('questionlook', 'cute'): 1,
#  ('cute', 'little'): 1,
#  ('little', 'go'): 1,
#  ('go', 'illustration'): 1,
#  ('illustration', 'alex'): 1,
#  ('alex', 'castro'): 1,
#  ('castro', 'verge'): 1,
#  ('verge', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'exchange'): 2,
#  ('exchange', 'coinbase'): 1,
#  ('coinbase', 'experiencing'): 1,
#  ('experiencing', 'partial'): 1,
#  ('partial', 'outage'): 1,
#  ('outage', 'morning'): 2,
#  ('morning', 'entire'): 1,
#  ('entire', 'site'): 1,
#  ('site', 'application'): 1,
#  ('application', 'additionally'): 1,
#  ('additionally', 'coinbase'): 1,
#  ('coinbase', 'bin'): 1,
#  ('bin', 'last'): 1,
#  ('last', 'whenelon'): 1,
#  ('whenelon', 'tweeted'): 1,
#  ('tweeted', 'spoken'): 1,
#  ('spoken', 'team'): 1,
#  ('team', 'doge'): 1,
#  ('doge', 'developer'): 1,
#  ('developer', 'make'): 1,
#  ('make', 'coin'): 1,
#  ('coin', 'efficient'): 1,
#  ('efficient', 'impact'): 1,
#  ('impact', 'wa'): 1,
#  ('wa', 'predictable'): 1,
#  ('predictable', 'sent'): 1,
#  ('sent', 'dogecoin'): 1,
#  ('dogecoin', 'moon'): 1,
#  ('moon', 'wa'): 1,
#  ('wa', 'tesla'): 1,
#  ('tesla', 'ceo'): 4,
#  ('elon', 'changed'): 1,
#  ('changed', 'stance'): 1,
#  ('stance', 'cryptocurrencyback'): 1,
#  ('cryptocurrencyback', 'march'): 1,
#  ('march', 'announced'): 1,
#  ('announced', 'tesla'): 1,
#  ('tesla', 'wa'): 1,
#  ('wa', 'accepting'): 1,
#  ('bitcoin', 'electric'): 1,
#  ('electric', 'car'): 2,
#  ('car', 'earlier'): 1,
#  ('earlier', 'year'): 1,
#  ('year', 'ev'): 1,
#  ('ev', 'company'): 1,
#  ('company', 'even'): 1,
#  ('even', 'bought'): 1,
#  ('bought', 'billi'): 1,
#  ('billi', 'image'): 1,
#  ('image', 'copyrightgetty'): 1,
#  ('copyrightgetty', 'imagesimage'): 1,
#  ('imagesimage', 'captionelon'): 1,
#  ('captionelon', 'musks'): 1,
#  ('musks', 'tesla'): 1,
#  ('tesla', 'seen'): 1,
#  ('seen', 'jump'): 1,
#  ('jump', 'profitstesla'): 1,
#  ('profitstesla', 'posted'): 1,
#  ('posted', 'first'): 1,
#  ('first', 'quarter'): 3,
#  ('quarter', 'profit'): 1,
#  ('profit', 'bolstered'): 1,
#  ('bolstered', 'sale'): 1,
#  ('sale', 'bitcoin'): 1,
#  ('bitcoin', 'environmental'): 1,
#  ('environmental', 'credit'): 1,
#  ('credit', 'earth'): 1,
#  ('earth', 'day'): 1,
#  ('day', 'prime'): 1,
#  ('prime', 'time'): 1,
#  ('time', 'brand'): 1,
#  ('brand', 'people'): 1,
#  ('people', 'promote'): 1,
#  ('promote', 'preexisting'): 1,
#  ('preexisting', 'product'): 1,
#  ('product', 'mass'): 1,
#  ('mass', 'swaddled'): 1,
#  ('swaddled', 'green'): 1,
#  ('green', 'package'): 1,
#  ('package', 'perhaps'): 1,
#  ('perhaps', 'surprise'): 1,
#  ('surprise', 'area'): 1,
#  ('area', 'shaman'): 1,
#  ('shaman', 'jack'): 1,
#  ('jack', 'dorsey'): 2,
#  ('dorsey', 'meme'): 1,
#  ('meme', 'en'): 1,
#  ('en', 'love'): 1,
#  ('love', 'affair'): 1,
#  ('affair', 'elon'): 1,
#  ('elon', 'bitcoin'): 1,
#  ('bitcoin', 'become'): 2,
#  ('become', 'complicatedits'): 1,
#  ('complicatedits', 'rough'): 1,
#  ('rough', 'couple'): 1,
#  ('couple', 'day'): 1,
#  ('day', 'crypto'): 1,
#  ('crypto', 'world'): 1,
#  ('world', 'price'): 1,
#  ('price', 'major'): 1,
#  ('major', 'crypto'): 1,
#  ('crypto', 'asset'): 1,
#  ('asset', 'plummeting'): 1,
#  ('plummeting', 'bitcoin'): 1,
#  ('bitcoin', 'partic'): 1,
#  ('partic', 'three'): 1,
#  ('three', 'year'): 1,
#  ('year', 'inception'): 1,
#  ('inception', 'crypto'): 1,
#  ('crypto', 'financial'): 1,
#  ('financial', 'service'): 1,
#  ('service', 'provider'): 2,
#  ('provider', 'babel'): 1,
#  ('babel', 'finance'): 1,
#  ('finance', 'racking'): 1,
#  ('racking', 'funding'): 1,
#  ('funding', 'partnership'): 1,
#  ('partnership', 'major'): 1,
#  ('major', 'institutional'): 1,
#  ('institutional', 'investor'): 1,
#  ('investor', 'startup'): 1,
#  ('startup', 'said'): 1,
#  ('said', 'monday'): 1,
#  ('monday', 'closed'): 1,
#  ('closed', 'bitcoin'): 1,
#  ('bitcoin', 'ethereum'): 3,
#  ('ethereum', 'host'): 1,
#  ('host', 'altcoins'): 1,
#  ('altcoins', 'suffered'): 1,
#  ('suffered', 'massive'): 1,
#  ('massive', 'drop'): 1,
#  ('drop', 'tuesday'): 1,
#  ('tuesday', 'night'): 1,
#  ('night', 'wednesday'): 1,
#  ('wednesday', 'morning'): 1,
#  ('morning', 'erasing'): 1,
#  ('erasing', 'month'): 1,
#  ('month', 'gain'): 1,
#  ('gain', 'hundred'): 1,
#  ('hundred', 'billion'): 1,
#  ('billion', 'market'): 1,
#  ('market', 'cap'): 1,
#  ('cap', 'overall'): 1,
#  ('overall', 'crypto'): 1,
#  ('crypto', 'market'): 1,
#  ('market', 'shrunk'): 1,
#  ('shrunk', 'new'): 1,
#  ('new', 'york'): 6,
#  ('york', 'cnn'): 1,
#  ('cnn', 'businessbitcoin'): 1,
#  ('businessbitcoin', 'price'): 1,
#  ('continued', 'rebound'): 1,
#  ('rebound', 'saturday'): 1,
#  ('saturday', 'rising'): 1,
#  ('rising', 'nearly'): 1,
#  ('nearly', 'world'): 1,
#  ('world', 'largest'): 1,
#  ('largest', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'overshadowed'): 1,
#  ('overshadowed', 'lately'): 1,
#  ('lately', 'younger'): 1,
#  ('younger', 'sibling'): 1,
#  ('sibling', 'isnt'): 1,
#  ('isnt', 'greatest'): 1,
#  ('greatest', 'time'): 1,
#  ('time', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'trader'): 1,
#  ('trader', 'coinbase'): 1,
#  ('coinbase', 'suffered'): 1,
#  ('suffered', 'hourslong'): 1,
#  ('hourslong', 'outage'): 1,
#  ('morning', 'may'): 1,
#  ('may', 'th'): 1,
#  ('th', 'hindered'): 1,
#  ('hindered', 'transaction'): 1,
#  ('transaction', 'exchange'): 1,
#  ('exchange', 'company'): 1,
#  ('company', 'pinpointed'): 1,
#  ('pinpointed', 'come'): 1,
#  ('come', 'ransomware'): 1,
#  ('ransomware', 'dont'): 1,
#  ('dont', 'always'): 1,
#  ('always', 'get'): 1,
#  ('get', 'pay'): 1,
#  ('pay', 'forcolonial'): 1,
#  ('forcolonial', 'pipeline'): 1,
#  ('pipeline', 'operates'): 1,
#  ('operates', 'mile'): 1,
#  ('mile', 'fuel'): 1,
#  ('fuel', 'pipeline'): 1,
#  ('pipeline', 'united'): 1,
#  ('united', 'states'): 1,
#  ('states', 'found'): 1,
#  ('found', 'hard'): 1,
#  ('hard', 'way'): 1,
#  ('way', 'two'): 1,
#  ('two', 'founder'): 1,
#  ('founder', 'crusoe'): 1,
#  ('crusoe', 'energy'): 1,
#  ('energy', 'think'): 1,
#  ('think', 'may'): 1,
#  ('may', 'solution'): 1,
#  ('solution', 'two'): 1,
#  ('two', 'largest'): 1,
#  ('largest', 'problem'): 1,
#  ('problem', 'facing'): 1,
#  ('facing', 'planet'): 1,
#  ('planet', 'today'): 1,
#  ('today', 'increasing'): 1,
#  ('increasing', 'energy'): 1,
#  ('energy', 'footprint'): 1,
#  ('footprint', 'tech'): 1,
#  ('tech', 'industry'): 1,
#  ('industry', 'greenhouse'): 1,
#  ('greenhouse', 'gas'): 1,
#  ('gas', 'e'): 1,
#  ('e', 'elon'): 1,
#  ('elon', 'really'): 1,
#  ('really', 'really'): 1,
#  ('really', 'like'): 1,
#  ('like', 'dogecoinafter'): 1,
#  ('dogecoinafter', 'endlessly'): 1,
#  ('endlessly', 'shilling'): 1,
#  ('shilling', 'joke'): 1,
#  ('joke', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'twitter'): 1,
#  ('twitter', 'interview'): 1,
#  ('interview', 'television'): 1,
#  ('television', 'announcing'): 1,
#  ('announcing', 'company'): 1,
#  ('company', 'spacex'): 1,
#  ('spacex', 'literally'): 1,
#  ('literally', 'se'): 1,
#  ('se', 'going'): 1,
#  ('going', 'moonthe'): 1,
#  ('moonthe', 'proponent'): 1,
#  ('proponent', 'dogecoin'): 1,
#  ('dogecoin', 'doge'): 1,
#  ('doge', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'started'): 1,
#  ('started', 'joke'): 1,
#  ('joke', 'one'): 1,
#  ('one', 'popular'): 1,
#  ('popular', 'coin'): 1,
#  ('coin', 'around'): 1,
#  ('around', 'would'): 1,
#  ('would', 'believe'): 1,
#  ('believe', 'sentence'): 1,
#  ('sentence', 'hello'): 1,
#  ('hello', 'friend'): 1,
#  ('friend', 'welcome'): 1,
#  ('welcome', 'back'): 1,
#  ('back', 'reviewlast'): 1,
#  ('reviewlast', 'wrote'): 1,
#  ('wrote', 'facebooks'): 1,
#  ('facebooks', 'neverending'): 1,
#  ('neverending', 'trump'): 1,
#  ('trump', 'problem'): 1,
#  ('problem', 'im'): 1,
#  ('im', 'looking'): 1,
#  ('looking', 'elon'): 1,
#  ('elon', 'musks'): 6,
#  ('musks', 'wild'): 1,
#  ('wild', 'whipping'): 1,
#  ('whipping', 'crypto'): 1,
#  ('crypto', 'marketsif'): 1,
#  ('marketsif', 'australian'): 1,
#  ('australian', 'computer'): 1,
#  ('computer', 'scientist'): 1,
#  ('scientist', 'alleges'): 1,
#  ('alleges', 'created'): 1,
#  ('created', 'bitcoin'): 1,
#  ('bitcoin', 'launched'): 1,
#  ('launched', 'london'): 1,
#  ('london', 'high'): 1,
#  ('high', 'court'): 1,
#  ('court', 'lawsuit'): 1,
#  ('lawsuit', 'software'): 1,
#  ('software', 'developer'): 1,
#  ('developer', 'effort'): 1,
#  ('effort', 'secure'): 1,
#  ('secure', 'bitcoin'): 1,
#  ('bitcoin', 'worth'): 1,
#  ('worth', 'around'): 1,
#  ('around', 'billion'): 1,
#  ('billion', 'pound'): 1,
#  ('pound', 'bitcoin'): 1,
#  ('bitcoin', 'rebounded'): 1,
#  ('rebounded', 'asian'): 1,
#  ('asian', 'trading'): 1,
#  ('trading', 'thursday'): 2,
#  ('thursday', 'plunging'): 1,
#  ('plunging', 'elon'): 1,
#  ('elon', 'tweeted'): 1,
#  ('tweeted', 'tesla'): 1,
#  ('tesla', 'inc'): 6,
#  ('inc', 'tslao'): 3,
#  ('tslao', 'stopped'): 1,
#  ('bitcoin', 'purchase'): 4,
#  ('purchase', 'vehicle'): 5,
#  ('vehicle', 'due'): 1,
#  ('due', 'representation'): 1,
#  ('representation', 'virtual'): 6,
#  ('virtual', 'currency'): 8,
#  ('currency', 'bitcoin'): 10,
#  ('bitcoin', 'us'): 1,
#  ('us', 'one'): 1,
#  ('one', 'dollar'): 1,
#  ('dollar', 'banknote'): 2,
#  ('banknote', 'seen'): 1,
#  ('seen', 'front'): 6,
#  ('front', 'stock'): 5,
#  ('stock', 'graph'): 5,
#  ('graph', 'illustration'): 5,
#  ('illustration', 'taken'): 8,
#  ('taken', 'january'): 2,
#  ('january', 'reutersdado'): 2,
#  ('reutersdado', 'ruvicfile'): 1,
#  ('ruvicfile', 'phototesla'): 1,
#  ('phototesla', 'inc'): 1,
#  ('inc', 'tsla'): 1,
#  ('tsla', 'reuters'): 1,
#  ('reuters', 'staffmay'): 4,
#  ('staffmay', 'reuters'): 4,
#  ('reuters', 'tesla'): 2,
#  ('inc', 'suspended'): 1,
#  ('suspended', 'use'): 3,
#  ('use', 'bitcoin'): 3,
#  ('vehicle', 'chief'): 1,
#  ('chief', 'executive'): 4,
#  ('executive', 'officer'): 4,
#  ('officer', 'elon'): 3,
#  ('elon', 'said'): 4,
#  ('said', 'tweet'): 3,
#  ('tweet', 'citing'): 1,
#  ('citing', 'concern'): 1,
#  ('concern', 'use'): 1,
#  ('use', 'fossil'): 2,
#  ('fuel', 'b'): 1,
#  ('b', 'cryptocurrency'): 1,
#  ('exchange', 'platform'): 1,
#  ('platform', 'coinbase'): 1,
#  ('coinbase', 'caved'): 1,
#  ('caved', 'long'): 1,
#  ('long', 'silence'): 1,
#  ('silence', 'hoard'): 1,
#  ('hoard', 'imploring'): 1,
#  ('imploring', 'company'): 1,
#  ('company', 'let'): 1,
#  ('let', 'trade'): 1,
#  ('trade', 'dogecoin'): 1,
#  ('dogecoin', 'theyve'): 1,
#  ('theyve', 'decided'): 1,
#  ('decided', 'list'): 1,
#  ('list', 'meme'): 1,
#  ('meme', 'adding'): 1,
#  ('adding', 'sheen'): 1,
#  ('sheen', 'legiti'): 1,
#  ('legiti', 'jack'): 1,
#  ('dorsey', 'cofounder'): 1,
#  ('cofounder', 'ceo'): 1,
#  ('ceo', 'twitter'): 1,
#  ('twitter', 'tweeted'): 1,
#  ('tweeted', 'wednesday'): 1,
#  ('wednesday', 'bitcoin'): 1,
#  ('bitcoin', 'incentivises'): 1,
#  ('incentivises', 'renewable'): 1,
#  ('renewable', 'energy'): 1,
#  ('energy', 'elon'): 1,
#  ('elon', 'responded'): 1,
#  ('responded', 'truethe'): 1,
#  ('truethe', 'bbc'): 1,
#  ('bbc', 'add'): 1,
#  ('add', 'tweet'): 1,
#  ('tweet', 'came'): 1,
#  ('came', 'despite'): 1,
#  ('despite', 'expert'): 1,
#  ('expert', 'warni'): 1,
#  ('warni', 'coinswitch'): 1,
#  ('coinswitch', 'kuber'): 1,
#  ('kuber', 'startup'): 1,
#  ('startup', 'allows'): 1,
#  ('allows', 'young'): 1,
#  ('young', 'user'): 1,
#  ('user', 'india'): 1,
#  ('india', 'invest'): 1,
#  ('invest', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'said'): 1,
#  ('said', 'thursday'): 1,
#  ('thursday', 'raised'): 1,
#  ('raised', 'million'): 1,
#  ('million', 'new'): 1,
#  ('new', 'financing'): 1,
#  ('financing', 'round'): 1,
#  ('round', 'look'): 1,
#  ('look', 'expand'): 1,
#  ('expand', 'reach'): 1,
#  ('reach', 'indi'): 1,
#  ('indi', 'tesla'): 1,
#  ('elon', 'say'): 3,
#  ('say', 'company'): 1,
#  ('company', 'suspended'): 1,
#  ('suspended', 'purchase'): 1,
#  ('vehicle', 'using'): 1,
#  ('using', 'bitcoinwe'): 1,
#  ('bitcoinwe', 'concerned'): 1,
#  ('concerned', 'rapidly'): 1,
#  ('rapidly', 'increasing'): 1,
#  ('increasing', 'use'): 1,
#  ('fuel', 'bitcoin'): 1,
#  ('bitcoin', 'mining'): 3,
#  ('mining', 'transaction'): 1,
#  ('transaction', 'especi'): 1,
#  ('especi', 'reuters'): 1,
#  ('reuters', 'stafffile'): 2,
#  ('stafffile', 'photo'): 2,
#  ('photo', 'tesla'): 1,
#  ('tesla', 'supercharger'): 2,
#  ('supercharger', 'shown'): 2,
#  ('shown', 'charging'): 2,
#  ('charging', 'station'): 2,
#  ('station', 'santa'): 2,
#  ('santa', 'clarita'): 2,
#  ('clarita', 'california'): 2,
#  ('california', 'us'): 3,
#  ('us', 'october'): 2,
#  ('october', 'reutersmike'): 2,
#  ('reutersmike', 'blakereuters'): 1,
#  ('blakereuters', 'tesla'): 1,
#  ('inc', 'recorded'): 1,
#  ('recorded', 'million'): 1,
#  ('million', 'logo'): 1,
#  ('logo', 'bitcoin'): 3,
#  ('bitcoin', 'digital'): 2,
#  ('digital', 'currency'): 6,
#  ('currency', 'seen'): 2,
#  ('seen', 'shop'): 2,
#  ('shop', 'marseille'): 2,
#  ('marseille', 'france'): 2,
#  ('france', 'february'): 2,
#  ('february', 'reuterseric'): 2,
#  ('reuterseric', 'gaillardbitcoin'): 1,
#  ('gaillardbitcoin', 'rose'): 1,
#  ('rose', 'friday'): 1,
#  ('friday', 'adding'): 1,
#  ('adding', 'previous'): 2,
#  ('previous', 'cl'): 1,
#  ('cl', 'reuters'): 1,
#  ('reuters', 'staffapril'): 1,
#  ('staffapril', 'reuters'): 1,
#  ('reuters', 'bitcoin'): 3,
#  ('bitcoin', 'dropped'): 3,
#  ('dropped', 'saturday'): 1,
#  ('saturday', 'losing'): 1,
#  ('losing', 'previous'): 1,
#  ('previous', 'closebitcoin'): 2,
#  ('closebitcoin', 'world'): 2,
#  ('world', 'biggest'): 2,
#  ('biggest', 'bestknown'): 2,
#  ('bestknown', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'representation'): 2,
#  ('bitcoin', 'seen'): 5,
#  ('seen', 'motherboard'): 1,
#  ('motherboard', 'picture'): 2,
#  ('picture', 'illustration'): 2,
#  ('taken', 'april'): 2,
#  ('april', 'reutersdado'): 2,
#  ('reutersdado', 'ruvicillustrationfile'): 3,
#  ('ruvicillustrationfile', 'photofile'): 1,
#  ('photofile', 'photobitcoin'): 1,
#  ('photobitcoin', 'dropped'): 1,
#  ('dropped', 'representations'): 1,
#  ('representations', 'virtual'): 1,
#  ('bitcoin', 'placed'): 1,
#  ('placed', 'us'): 1,
#  ('us', 'dollar'): 2,
#  ('banknote', 'illustration'): 1,
#  ('taken', 'may'): 3,
#  ('may', 'reutersdado'): 3,
#  ('reutersdado', 'ruvicbitcoin'): 1,
#  ('ruvicbitcoin', 'rose'): 1,
#  ('rose', 'gmt'): 2,
#  ('gmt', 'wednesday'): 1,
#  ('wednesday', 'ad'): 1,
#  ('ad', 'washington'): 1,
#  ('washington', 'reuters'): 1,
#  ('reuters', 'breakingviews'): 1,
#  ('breakingviews', 'classic'): 1,
#  ('classic', 'ransom'): 1,
#  ('ransom', 'suitcase'): 1,
#  ('suitcase', 'full'): 1,
#  ('full', 'unmarked'): 1,
#  ('unmarked', 'us'): 1,
#  ('dollar', 'bill'): 1,
#  ('bill', 'bitcoins'): 1,
#  ('bitcoins', 'role'): 1,
#  ('role', 'colonial'): 1,
#  ('colonial', 'pipeline'): 2,
#  ('pipeline', 'hack'): 1,
#  ('hack', 'show'): 1,
#  ('show', 'global'): 1,
#  ('global', 'currency'): 1,
#  ('currency', 'crime'): 1,
#  ('crime', 'rival'): 1,
#  ('rival', 'companies'): 1,
#  ('companies', 'exposed'): 1,
#  ('exposed', 'bitcoin'): 1,
#  ('bitcoin', 'slid'): 1,
#  ('slid', 'monday'): 1,
#  ('monday', 'wake'): 1,
#  ('wake', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'plunging'): 1,
#  ('plunging', 'lowest'): 1,
#  ('lowest', 'level'): 1,
#  ('level', 'since'): 1,
#  ('since', 'february'): 1,
#  ('february', 'elon'): 1,
#  ('elon', 'suggested'): 1,
#  ('suggested', 'tesla'): 2,
#  ('tesla', 'might'): 1,
#  ('might', 'sold'): 1,
#  ('sold', 'holding'): 1,
#  ('holding', 'weekend'): 1,
#  ('weekend', 'april'): 1,
#  ('april', 'min'): 3,
#  ('min', 'readthis'): 1,
#  ('readthis', 'story'): 1,
#  ('story', 'originally'): 1,
#  ('originally', 'appeared'): 1,
#  ('appeared', 'marketbeattime'): 1,
#  ('marketbeattime', 'start'): 1,
#  ('start', 'buying'): 1,
#  ('buying', 'bitcoin'): 1,
#  ('bitcoin', 'againwith'): 1,
#  ('againwith', 'bitcoin'): 1,
#  ('bitcoin', 'sure'): 3,
#  ('sure', 'bitcoin'): 1,
#  ('bitcoin', 'crypto'): 1,
#  ('crypto', 'btc'): 1,
#  ('btc', 'holder'): 1,
#  ('holder', 'sudden'): 1,
#  ('sudden', 'unexpected'): 1,
#  ('unexpected', 'death'): 1,
#  ('death', 'millions'): 1,
#  ('millions', 'dollar'): 1,
#  ('dollar', 'worth'): 1,
#  ('worth', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'gone'): 1,
#  ('gone', 'amateur'): 1,
#  ('amateur', 'detective'): 1,
#  ('detective', 'poring'): 1,
#  ('poring', 'digital'): 1,
#  ('digital', 'puzzle'): 1,
#  ('puzzle', 'piece'): 1,
#  ('piece', 'desperate'): 1,
#  ('desperate', 'bid'): 1,
#  ('bid', 'reclaim'): 1,
#  ('reclaim', 'whats'): 1,
#  ('whats', 'theirsif'): 1,
#  ('theirsif', 'paid'): 1,
#  ('paid', 'attent'): 1,
#  ('attent', 'stocks'): 1,
#  ('stocks', 'exposed'): 1,
#  ('exposed', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'slumped'): 1,
#  ('slumped', 'globally'): 1,
#  ('globally', 'elon'): 1,
#  ('elon', 'voiced'): 1,
#  ('voiced', 'concern'): 1,
#  ('concern', 'bitcoins'): 1,
#  ('bitcoins', 'energy'): 1,
#  ('energy', 'usage'): 2,
#  ('usage', 'delivering'): 1,
#  ('delivering', 'blow'): 1,
#  ('blow', 'digital'): 1,
#  ('digital', 'money'): 1,
#  ('money', 'standing'): 1,
#  ('standing', 'within'): 1,
#  ('within', 'global'): 1,
#  ('global', 'market'): 1,
#  ('market', 'month'): 1,
#  ('month', 'elon'): 1,
#  ('elon', 'stepped'): 1,
#  ('stepped', 'criticism'): 1,
#  ('criticism', 'bitcoin'): 1,
#  ('bitcoin', 'environmentally'): 1,
#  ('environmentally', 'unsustainable'): 1,
#  ('unsustainable', 'also'): 1,
#  ('also', 'signaling'): 1,
#  ('signaling', 'support'): 1,
#  ('support', 'another'): 1,
#  ('another', 'digital'): 1,
#  ('digital', 'coin'): 1,
#  ('coin', 'saying'): 1,
#  ('saying', 'remains'): 1,
#  ('remains', 'believer'): 1,
#  ('believer', 'cryptocurrencythe'): 1,
#  ('cryptocurrencythe', 'tesla'): 1,
#  ('inc', 'concise'): 1,
#  ('concise', 'insight'): 1,
#  ('insight', 'global'): 1,
#  ('global', 'financeanother'): 1,
#  ('financeanother', 'day'): 1,
#  ('day', 'another'): 1,
#  ('another', 'crypto'): 1,
#  ('crypto', 'still'): 1,
#  ('still', 'rare'): 1,
#  ('rare', 'people'): 1,
#  ('people', 'paid'): 1,
#  ('paid', 'bitcoin'): 1,
#  ('bitcoin', 'including'): 1,
#  ('including', 'us'): 1,
#  ('us', 'athlete'): 1,
#  ('athlete', 'colonial'): 1,
#  ('pipeline', 'soon'): 1,
#  ('soon', 'resume'): 1,
#  ('resume', 'normal'): 1,
#  ('normal', 'operation'): 1,
#  ('operation', 'forced'): 1,
#  ('forced', 'shut'): 1,
#  ('shut', 'due'): 1,
#  ('due', 'ransomware'): 1,
#  ('ransomware', 'attack'): 1,
#  ('attack', 'company'): 1,
#  ('company', 'announced'): 1,
#  ('announced', 'initiated'): 1,
#  ('initiated', 'return'): 1,
#  ('return', 'service'): 1,
#  ('service', 'pm'): 1,
#  ('pm', 'easte'): 1,
#  ('easte', 'first'): 1,
#  ('first', 'let'): 1,
#  ('let', 'understand'): 1,
#  ('understand', 'wordsbitcoin'): 1,
#  ('wordsbitcoin', 'blockchain'): 1,
#  ('blockchain', 'blockchain'): 1,
#  ('blockchain', 'printing'): 1,
#  ('printing', 'press'): 1,
#  ('press', 'bitcoin'): 1,
#  ('bitcoin', 'kind'): 1,
#  ('kind', 'paper'): 1,
#  ('paper', 'money'): 1,
#  ('money', 'countless'): 1,
#  ('countless', 'thing'): 1,
#  ('thing', 'one'): 1,
#  ('one', 'printi'): 1,
#  ('printi', 'reuters'): 1,
#  ('reuters', 'peter'): 1,
#  ('peter', 'thielbacked'): 1,
#  ('thielbacked', 'us'): 1,
#  ('us', 'analytics'): 1,
#  ('analytics', 'company'): 1,
#  ('company', 'palantir'): 1,
#  ('palantir', 'technologies'): 1,
#  ('technologies', 'inc'): 1,
#  ('inc', 'said'): 3,
#  ('said', 'tuesday'): 3,
#  ('tuesday', 'accepts'): 1,
#  ('accepts', 'bitcoin'): 1,
#  ('payment', 'customersthe'): 1,
#  ('customersthe', 'company'): 1,
#  ('company', 'also'): 1,
#  ('also', 'said'): 1,
#  ('said', 'wa'): 1,
#  ('wa', 'co'): 1,
#  ('co', 'bitcoin'): 1,
#  ('dropped', 'threemonth'): 2,
#  ('threemonth', 'low'): 3,
#  ('low', 'monday'): 3,
#  ('monday', 'investor'): 2,
#  ('investor', 'sold'): 2,
#  ('sold', 'cryptocurrencies'): 2,
#  ('cryptocurrencies', 'wake'): 3,
#  ('wake', 'tesla'): 3,
#  ('tesla', 'bos'): 4,
#  ('bos', 'elon'): 5,
#  ('musks', 'hinting'): 2,
#  ('hinting', 'weekend'): 2,
#  ('weekend', 'carmarker'): 1,
#  ('carmarker', 'considering'): 1,
#  ('considering', 'may'): 2,
#  ('may', 'already'): 1,
#  ('already', 'posted'): 1,
#  ('posted', 'bitcoin'): 1,
#  ('bitcoin', 'rallied'): 1,
#  ('rallied', 'threemonth'): 1,
#  ('monday', 'volatile'): 1,
#  ('volatile', 'session'): 1,
#  ('session', 'saw'): 1,
#  ('saw', 'investor'): 1,
#  ('investor', 'initially'): 1,
#  ('initially', 'selling'): 1,
#  ('selling', 'buying'): 1,
#  ('buying', 'cryptocurrencies'): 1,
#  ('musks', 'tweet'): 1,
#  ('tweet', 'reuters'): 1,
#  ('reuters', 'staffsingapore'): 1,
#  ('staffsingapore', 'reuters'): 1,
#  ('weekend', 'carmar'): 1,
#  ('carmar', 'reuters'): 1,
#  ('photo', 'representation'): 1,
#  ('taken', 'march'): 2,
#  ('march', 'reutersdado'): 2,
#  ('ruvicillustrationfile', 'photore'): 1,
#  ('photore', 'price'): 1,
#  ('price', 'bitcoin'): 2,
#  ('bitcoin', 'traded'): 1,
#  ('traded', 'sunday'): 1,
#  ('sunday', 'tweet'): 1,
#  ('tweet', 'tesla'): 1,
#  ('elon', 'outspoken'): 1,
#  ('outspoken', 'supporter'): 1,
#  ('supporter', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'suggested'): 1,
#  ('tesla', 'may'): 1,
#  ('may', 'considering'): 1,
#  ('may', 'sold'): 1,
#  ('sold', 'bitcoin'): 1,
#  ('bitcoin', 'elon'): 2,
#  ('elon', 'hit'): 1,
#  ('hit', 'back'): 1,
#  ('back', 'critic'): 1,
#  ('critic', 'claimed'): 1,
#  ('claimed', 'pumped'): 1,
#  ('pumped', 'dumped'): 1,
#  ('dumped', 'bitcoin'): 1,
#  ('bitcoin', 'make'): 1,
#  ('make', 'fortune'): 1,
#  ('fortune', 'tesla'): 1,
#  ('tesla', 'reported'): 1,
#  ('reported', 'first'): 1,
#  ('quarter', 'earnings'): 1,
#  ('earnings', 'surpassed'): 1,
#  ('surpassed', 'market'): 1,
#  ('market', 'expectation'): 1,
#  ('expectation', 'company'): 1,
#  ('company', 'appears'): 1,
#  ('appears', 'bitcoin'): 1,
#  ('become', 'available'): 1,
#  ('available', 'customer'): 1,
#  ('customer', 'hundred'): 1,
#  ('hundred', 'bank'): 1,
#  ('bank', 'us'): 1,
#  ('us', 'year'): 1,
#  ('year', 'according'): 1,
#  ('according', 'cnbc'): 1,
#  ('cnbc', 'report'): 1,
#  ('report', 'wednesdaycrypto'): 1,
#  ('wednesdaycrypto', 'custody'): 1,
#  ('custody', 'firm'): 1,
#  ('firm', 'nydig'): 1,
#  ('nydig', 'teamed'): 1,
#  ('teamed', 'fintech'): 1,
#  ('company', 'fidelity'): 1,
#  ('fidelity', 'nati'): 1,
#  ('nati', 'april'): 1,
#  ('min', 'readopinions'): 1,
#  ('readopinions', 'expressed'): 1,
#  ('expressed', 'entrepreneur'): 2,
#  ('entrepreneur', 'contributor'): 2,
#  ('contributor', 'ownbitcoin'): 1,
#  ('ownbitcoin', 'rose'): 1,
#  ('rose', 'reaching'): 1,
#  ('reaching', 'total'): 1,
#  ('total', 'worth'): 1,
#  ('worth', 'coindesk'): 1,
#  ('coindesk', 'reported'): 1,
#  ('reported', 'monday'): 1,
#  ('monday', 'financial'): 1,
#  ('financial', 'exp'): 1,
#  ('exp', 'get'): 1,
#  ('get', 'roundup'): 1,
#  ('roundup', 'techcrunchs'): 1,
#  ('techcrunchs', 'biggest'): 1,
#  ('biggest', 'important'): 1,
#  ('important', 'story'): 1,
#  ('story', 'delivered'): 1,
#  ('delivered', 'inbox'): 1,
#  ('inbox', 'every'): 1,
#  ('every', 'day'): 1,
#  ('day', 'pm'): 1,
#  ('pm', 'pdt'): 1,
#  ('pdt', 'subscribe'): 1,
#  ('subscribe', 'herei'): 1,
#  ('herei', 'interrupt'): 1,
#  ('interrupt', 'regularly'): 1,
#  ('regularly', 'scheduled'): 1,
#  ('scheduled', 'daily'): 1,
#  ('daily', 'crunch'): 2,
#  ('crunch', 'announce'): 1,
#  ('announce', 'bitcoin'): 1,
#  ('bitcoin', 'logo'): 1,
#  ('logo', 'displayed'): 1,
#  ('displayed', 'bitcoin'): 1,
#  ('bitcoin', 'center'): 1,
#  ('center', 'new'): 1,
#  ('york', 'city'): 1,
#  ('city', 'new'): 1,
#  ('new', 'yorks'): 1,
#  ('yorks', 'financial'): 1,
#  ('financial', 'district'): 1,
#  ('district', 'july'): 1,
#  ('july', 'reutersbrendan'): 1,
#  ('reutersbrendan', 'mcdermidus'): 1,
#  ('mcdermidus', 'official'): 1,
#  ('official', 'tuesday'): 1,
#  ('tuesday', 'arrested'): 1,
#  ('arrested', 'roman'): 1,
#  ('roman', 'sterlingov'): 1,
#  ('sterlingov', 'allege'): 1,
#  ('allege', 'get'): 1,
#  ('get', 'close'): 1,
#  ('close', 'robotic'): 1,
#  ('robotic', 'groot'): 1,
#  ('groot', 'spacex'): 1,
#  ('spacex', 'successful'): 1,
#  ('successful', 'astronaut'): 1,
#  ('astronaut', 'launch'): 1,
#  ('launch', 'cryptocurrency'): 1,
#  ('price', 'tumble'): 1,
#  ('tumble', 'daily'): 1,
#  ('crunch', 'april'): 1,
#  ('april', 'big'): 1,
#  ('big', 'story'): 1,
#  ('story', 'meet'): 1,
#  ('meet', 'disney'): 1,
#  ('disney', 'imagineering'): 1,
#  ('imagineering', 'elon'): 1,
#  ('elon', 'helped'): 1,
#  ('helped', 'legitimize'): 1,
#  ('legitimize', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'eye'): 1,
#  ('eye', 'wall'): 1,
#  ('wall', 'street'): 2,
#  ('street', 'investor'): 2,
#  ('investor', 'tweet'): 1,
#  ('tweet', 'scaring'): 1,
#  ('scaring', 'offabout'): 1,
#  ('offabout', 'quarter'): 1,
#  ('quarter', 'bitcoins'): 1,
#  ('bitcoins', 'value'): 1,
#  ('value', 'wiped'): 1,
#  ('wiped', 'away'): 1,
#  ('away', 'span'): 1,
#  ('span', 'price'): 1,
#  ('bitcoin', 'fell'): 1,
#  ('fell', 'wednesday'): 1,
#  ('wednesday', 'china'): 1,
#  ('china', 'banking'): 1,
#  ('banking', 'association'): 1,
#  ('association', 'warned'): 1,
#  ('warned', 'member'): 1,
#  ('member', 'bank'): 1,
#  ('bank', 'risk'): 1,
#  ('risk', 'associated'): 1,
#  ('associated', 'digital'): 1,
#  ('currency', 'digital'): 1,
#  ('currency', 'suffered'): 1,
#  ('suffered', 'sharp'): 1,
#  ('sharp', 'decline'): 1,
#  ('decline', 'ap'): 1,
#  ('ap', 'photogerry'): 1,
#  ('photogerry', 'broomestar'): 1,
#  ('broomestar', 'nfl'): 1,
#  ('nfl', 'quarterback'): 1,
#  ('quarterback', 'tom'): 1,
#  ('tom', 'brady'): 1,
#  ('brady', 'hinted'): 1,
#  ('hinted', 'become'): 1,
#  ('become', 'crypto'): 1,
#  ('crypto', 'investor'): 1,
#  ('investor', 'switching'): 1,
#  ('switching', 'twitter'): 1,
#  ('twitter', 'profile'): 1,
#  ('profile', 'picture'): 1,
#  ('picture', 'one'): 1,
#  ('one', 'feature'): 1,
#  ('feature', 'laser'): 1,
#  ('laser', 'eye'): 1,
#  ('eye', 'popular'): 1,
#  ('popular', 'among'): 1,
#  ('among', 'bitcoin'): 1,
#  ('bitcoin', 'reuters'): 1,
#  ('reuters', 'ether'): 1,
#  ('ether', 'world'): 2,
#  ('world', 'second'): 2,
#  ...}

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
eth_t = get_token(eth_df)

def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count

big_eth = bigram_counter(eth_t, 2)
big_eth
# Out:
# {('vitalik', 'buterin'): 6,
#  ('buterin', 'creator'): 1,
#  ('creator', 'ethereum'): 1,
#  ('ethereum', 'wednesday'): 1,
#  ('wednesday', 'donated'): 1,
#  ('donated', 'ethereum'): 1,
#  ('ethereum', 'meme'): 1,
#  ('meme', 'coin'): 1,
#  ('coin', 'worth'): 1,
#  ('worth', 'billion'): 1,
#  ('billion', 'one'): 1,
#  ('one', 'largestever'): 1,
#  ('largestever', 'individual'): 1,
#  ('individual', 'philanthropy'): 1,
#  ('philanthropy', 'effortsbuterin'): 1,
#  ('effortsbuterin', 'transferred'): 1,
#  ('transferred', 'eth'): 1,
#  ('eth', 'investor'): 1,
#  ('investor', 'call'): 1,
#  ('call', 'disruptive'): 1,
#  ('disruptive', 'innovator'): 1,
#  ('innovator', 'detractors'): 1,
#  ('detractors', 'like'): 1,
#  ('like', 'north'): 1,
#  ('north', 'carolina'): 1,
#  ('carolina', 'attorney'): 1,
#  ('attorney', 'general'): 1,
#  ('general', 'josh'): 1,
#  ('josh', 'stein'): 1,
#  ('stein', 'call'): 1,
#  ('call', 'dirty'): 1,
#  ('dirty', 'scammer'): 1,
#  ('scammer', 'leda'): 1,
#  ('leda', 'health'): 1,
#  ('health', 'cofounder'): 1,
#  ('cofounder', 'madison'): 1,
#  ('madison', 'campbell'): 1,
#  ('campbell', 'liesel'): 1,
#  ('liesel', 'vaidya'): 1,
#  ('vaidya', 'th'): 1,
#  ('th', 'solana'): 1,
#  ('solana', 'isnt'): 1,
#  ('isnt', 'known'): 1,
#  ('known', 'yet'): 1,
#  ('yet', 'outside'): 1,
#  ('outside', 'crypto'): 1,
#  ('crypto', 'community'): 1,
#  ('community', 'insider'): 1,
#  ('insider', 'think'): 1,
#  ('think', 'blockchain'): 1,
#  ('blockchain', 'platform'): 1,
#  ('platform', 'interesting'): 1,
#  ('interesting', 'wide'): 1,
#  ('wide', 'variety'): 1,
#  ('variety', 'reason'): 1,
#  ('reason', 'beginning'): 1,
#  ('beginning', 'amiable'): 1,
#  ('amiable', 'founder'): 1,
#  ('founder', 'anatoly'): 1,
#  ('anatoly', 'yakovenko'): 1,
#  ('yakovenko', 'new'): 1,
#  ('new', 'york'): 4,
#  ('york', 'cnn'): 1,
#  ('cnn', 'businessbitcoin'): 1,
#  ('businessbitcoin', 'price'): 1,
#  ('price', 'continued'): 2,
#  ('continued', 'rebound'): 1,
#  ('rebound', 'saturday'): 1,
#  ('saturday', 'rising'): 1,
#  ('rising', 'nearly'): 1,
#  ('nearly', 'world'): 1,
#  ('world', 'largest'): 1,
#  ('largest', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'overshadowed'): 1,
#  ('overshadowed', 'lately'): 1,
#  ('lately', 'younger'): 1,
#  ('younger', 'sibling'): 1,
#  ('sibling', 'creator'): 1,
#  ('creator', 'behind'): 1,
#  ('behind', 'cryptopunks'): 1,
#  ('cryptopunks', 'one'): 1,
#  ('one', 'popular'): 1,
#  ('popular', 'nft'): 1,
#  ('nft', 'project'): 1,
#  ('project', 'web'): 1,
#  ('web', 'revealed'): 1,
#  ('revealed', 'latest'): 1,
#  ('latest', 'project'): 1,
#  ('project', 'called'): 1,
#  ('called', 'meebits'): 1,
#  ('meebits', 'project'): 1,
#  ('project', 'boast'): 1,
#  ('boast', 'procedurally'): 1,
#  ('procedurally', 'generated'): 1,
#  ('generated', 'character'): 1,
#  ('character', 'tha'): 1,
#  ('tha', 'bitcoin'): 1,
#  ('bitcoin', 'ethereum'): 9,
#  ('ethereum', 'host'): 1,
#  ('host', 'altcoins'): 1,
#  ('altcoins', 'suffered'): 1,
#  ('suffered', 'massive'): 1,
#  ('massive', 'drop'): 1,
#  ('drop', 'tuesday'): 1,
#  ('tuesday', 'night'): 1,
#  ('night', 'wednesday'): 1,
#  ('wednesday', 'morning'): 1,
#  ('morning', 'erasing'): 1,
#  ('erasing', 'month'): 1,
#  ('month', 'gain'): 1,
#  ('gain', 'hundred'): 1,
#  ('hundred', 'billion'): 2,
#  ('billion', 'market'): 1,
#  ('market', 'cap'): 1,
#  ('cap', 'overall'): 1,
#  ('overall', 'crypto'): 1,
#  ('crypto', 'market'): 1,
#  ('market', 'shrunk'): 1,
#  ('shrunk', 'reuters'): 1,
#  ('reuters', 'stafffile'): 3,
#  ('stafffile', 'photo'): 3,
#  ('photo', 'representation'): 3,
#  ('representation', 'virtual'): 9,
#  ('virtual', 'currency'): 11,
#  ('currency', 'ethereum'): 6,
#  ('ethereum', 'seen'): 6,
#  ('seen', 'front'): 8,
#  ('front', 'stock'): 8,
#  ('stock', 'graph'): 8,
#  ('graph', 'illustration'): 8,
#  ('illustration', 'taken'): 11,
#  ('taken', 'february'): 6,
#  ('february', 'reutersdado'): 6,
#  ('reutersdado', 'ruvicillustrationsingapore'): 2,
#  ('ruvicillustrationsingapore', 'representation'): 1,
#  ('reutersdado', 'ruvicillustrationcryptocurrency'): 3,
#  ('ruvicillustrationcryptocurrency', 'ether'): 3,
#  ('ether', 'hit'): 4,
#  ('hit', 'record'): 5,
#  ('record', 'high'): 5,
#  ('high', 'took'): 1,
#  ('took', 'get'): 1,
#  ('get', 'dfinity'): 1,
#  ('dfinity', 'finally'): 1,
#  ('finally', 'launchingin'): 1,
#  ('launchingin', 'july'): 1,
#  ('july', 'went'): 1,
#  ('went', 'swiss'): 1,
#  ('swiss', 'city'): 1,
#  ('city', 'zug'): 1,
#  ('zug', 'speak'): 1,
#  ('speak', 'dominic'): 1,
#  ('dominic', 'williams'): 1,
#  ('williams', 'ceo'): 1,
#  ('ceo', 'crypto'): 1,
#  ('crypto', 'platform'): 1,
#  ('platform', 'dfinity'): 1,
#  ('dfinity', 'blockchain'): 1,
#  ('blockchain', 'project'): 1,
#  ('project', 'story'): 1,
#  ('story', 'originally'): 3,
#  ('originally', 'appeared'): 3,
#  ('appeared', 'stockmarketus'): 1,
#  ('stockmarketus', 'stock'): 1,
#  ('stock', 'futures'): 1,
#  ('futures', 'edge'): 1,
#  ('edge', 'higher'): 1,
#  ('higher', 'monday'): 1,
#  ('monday', 'morningthe'): 1,
#  ('morningthe', 'us'): 1,
#  ('us', 'stock'): 1,
#  ('stock', 'future'): 1,
#  ('future', 'moved'): 1,
#  ('moved', 'higher'): 1,
#  ('higher', 'premarket'): 1,
#  ('premarket', 'trading'): 1,
#  ('trading', 'monday'): 1,
#  ('monday', 'investor'): 3,
#  ('investor', 'prepare'): 1,
#  ('prepare', 'th'): 1,
#  ('th', 'article'): 1,
#  ('article', 'wa'): 5,
#  ('wa', 'translated'): 5,
#  ('translated', 'spanish'): 5,
#  ('spanish', 'edition'): 5,
#  ('edition', 'using'): 5,
#  ('using', 'ai'): 5,
#  ('ai', 'technology'): 5,
#  ('technology', 'errors'): 5,
#  ('errors', 'may'): 5,
#  ('may', 'exist'): 5,
#  ('exist', 'due'): 5,
#  ('due', 'processcryptocurrencies'): 2,
#  ('processcryptocurrencies', 'thing'): 1,
#  ('thing', 'today'): 1,
#  ('today', 'vitalik'): 1,
#  ('buterin', 'yearold'): 1,
#  ('yearold', 'cofounder'): 1,
#  ('cofounder', 'representation'): 1,
#  ('ether', 'extended'): 1,
#  ('extended', 'gain'): 1,
#  ('gain', 'posted'): 1,
#  ('posted', 'sampp'): 1,
#  ('sampp', 'dow'): 3,
#  ('dow', 'jones'): 4,
#  ('jones', 'indices'): 3,
#  ('indices', 'launched'): 2,
#  ('launched', 'new'): 3,
#  ('new', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'index'): 2,
#  ('index', 'mainstreaming'): 1,
#  ('mainstreaming', 'digital'): 1,
#  ('digital', 'currency'): 7,
#  ('currency', 'including'): 1,
#  ('including', 'bitcoin'): 1,
#  ('ethereum', 'bringing'): 1,
#  ('bringing', 'trading'): 1,
#  ('trading', 'floor'): 1,
#  ('floor', 'wall'): 1,
#  ('wall', 'stre'): 1,
#  ('stre', 'reuters'): 1,
#  ('reuters', 'staffsingapore'): 2,
#  ('staffsingapore', 'may'): 1,
#  ('may', 'reuters'): 3,
#  ('reuters', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'ether'): 4,
#  ('high', 'monday'): 5,
#  ('monday', 'trade'): 2,
#  ('trade', 'within'): 2,
#  ('within', 'whisker'): 2,
#  ('whisker', 'extending'): 2,
#  ('extending', 'last'): 1,
#  ('last', 'rally'): 1,
#  ('rally', 'wake'): 1,
#  ('wake', 'report'): 1,
#  ('report', 'europe'): 1,
#  ('europe', 'sothebys'): 1,
#  ('sothebys', 'said'): 1,
#  ('said', 'tuesday'): 2,
#  ('tuesday', 'would'): 1,
#  ('would', 'accept'): 1,
#  ('accept', 'bitcoin'): 1,
#  ('ethereum', 'payment'): 1,
#  ('payment', 'banksys'): 1,
#  ('banksys', 'iconic'): 1,
#  ('iconic', 'artwork'): 1,
#  ('artwork', 'love'): 1,
#  ('love', 'air'): 1,
#  ('air', 'first'): 1,
#  ('first', 'physical'): 1,
#  ('physical', 'art'): 1,
#  ('art', 'auction'): 1,
#  ('auction', 'latest'): 1,
#  ('latest', 'sign'): 1,
#  ('sign', 'growing'): 1,
#  ('growing', 'mainstrea'): 1,
#  ('mainstrea', 'new'): 1,
#  ('york', 'may'): 1,
#  ('reuters', 'ethereum'): 1,
#  ('ethereum', 'outperformed'): 2,
#  ('outperformed', 'major'): 2,
#  ('major', 'digital'): 2,
#  ('currency', 'rival'): 2,
#  ('rival', 'year'): 2,
#  ('year', 'bolstered'): 2,
#  ('bolstered', 'surge'): 2,
#  ('surge', 'decentralized'): 2,
#  ('decentralized', 'finance'): 4,
#  ('finance', 'defi'): 2,
#  ('defi', 'anticipation'): 2,
#  ('anticipation', 'technical'): 2,
#  ('technical', 'adjustment'): 2,
#  ('adjustment', 'th'): 1,
#  ('th', 'reuters'): 1,
#  ('reuters', 'staffadds'): 1,
#  ('staffadds', 'detail'): 1,
#  ('detail', 'reported'): 1,
#  ('reported', 'eib'): 1,
#  ('eib', 'plan'): 1,
#  ('plan', 'bitcoin'): 1,
#  ('bitcoin', 'pricesingapore'): 1,
#  ('pricesingapore', 'may'): 1,
#  ('extending', 'la'): 1,
#  ('la', 'ethereum'): 1,
#  ('adjustment', 'summer'): 1,
#  ('summer', 'face'): 1,
#  ('face', 'hurd'): 1,
#  ('hurd', 'reuters'): 1,
#  ('ruvicillustrationsingapore', 'april'): 1,
#  ('april', 'min'): 4,
#  ('min', 'readopinions'): 2,
#  ('readopinions', 'expressed'): 2,
#  ('expressed', 'entrepreneur'): 3,
#  ('entrepreneur', 'contributor'): 3,
#  ('contributor', 'ownthe'): 1,
#  ('ownthe', 'prevalent'): 1,
#  ('prevalent', 'economic'): 1,
#  ('economic', 'narrative'): 1,
#  ('narrative', 'year'): 1,
#  ('year', 'revolved'): 1,
#  ('revolved', 'around'): 1,
#  ('around', 'one'): 1,
#  ('one', 'concept'): 1,
#  ('concept', 'inflation'): 1,
#  ('inflation', 'year'): 1,
#  ('year', 'year'): 1,
#  ('year', 'april'): 1,
#  ('min', 'readthis'): 2,
#  ('readthis', 'article'): 1,
#  ('due', 'processafter'): 1,
#  ('processafter', 'bitcoin'): 1,
#  ('bitcoin', 'another'): 1,
#  ('another', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'capture'): 1,
#  ('capture', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'price'): 1,
#  ('continued', 'tumble'): 1,
#  ('tumble', 'friday'): 1,
#  ('friday', 'bitcoin'): 1,
#  ('bitcoin', 'leading'): 1,
#  ('leading', 'charge'): 1,
#  ('charge', 'price'): 1,
#  ('price', 'internet'): 1,
#  ('internet', 'currency'): 1,
#  ('currency', 'dipping'): 1,
#  ('dipping', 'first'): 1,
#  ('first', 'time'): 2,
#  ('time', 'since'): 2,
#  ('since', 'early'): 1,
#  ('early', 'marchbitcoin'): 1,
#  ('marchbitcoin', 'ro'): 1,
#  ('ro', 'coinbase'): 1,
#  ('coinbase', 'share'): 1,
#  ('share', 'tumbled'): 1,
#  ('tumbled', 'today'): 1,
#  ('today', 'lowest'): 1,
#  ('lowest', 'point'): 1,
#  ('point', 'since'): 1,
#  ('since', 'company'): 1,
#  ('company', 'began'): 1,
#  ('began', 'trading'): 1,
#  ('trading', 'publicly'): 1,
#  ('publicly', 'april'): 1,
#  ('april', 'market'): 1,
#  ('market', 'often'): 1,
#  ('often', 'move'): 1,
#  ('move', 'mysterious'): 1,
#  ('mysterious', 'way'): 1,
#  ('way', 'several'): 1,
#  ('several', 'driver'): 1,
#  ('driver', 'could'): 1,
#  ('could', 'play'): 1,
#  ('play', 'includ'): 1,
#  ('includ', 'gpu'): 1,
#  ('gpu', 'shortage'): 1,
#  ('shortage', 'inflated'): 1,
#  ('inflated', 'price'): 1,
#  ('price', 'become'): 1,
#  ('become', 'byproduct'): 1,
#  ('byproduct', 'growth'): 1,
#  ('growth', 'cryptomining'): 1,
#  ('cryptomining', 'needless'): 1,
#  ('needless', 'say'): 1,
#  ('say', 'thats'): 1,
#  ('thats', 'bad'): 1,
#  ('bad', 'news'): 1,
#  ('news', 'gamers'): 1,
#  ('gamers', 'make'): 1,
#  ('make', 'big'): 1,
#  ('big', 'chunk'): 1,
#  ('chunk', 'computing'): 1,
#  ('computing', 'industry'): 1,
#  ('industry', 'customer'): 1,
#  ('customer', 'illustration'): 1,
#  ('illustration', 'alex'): 1,
#  ('alex', 'castro'): 1,
#  ('castro', 'verge'): 1,
#  ('verge', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'exchange'): 2,
#  ('exchange', 'coinbase'): 1,
#  ('coinbase', 'experiencing'): 1,
#  ('experiencing', 'partial'): 1,
#  ('partial', 'outage'): 1,
#  ('outage', 'morning'): 1,
#  ('morning', 'entire'): 1,
#  ('entire', 'site'): 1,
#  ('site', 'application'): 1,
#  ('application', 'additionally'): 1,
#  ('additionally', 'coinbase'): 1,
#  ('coinbase', 'bin'): 1,
#  ('bin', 'bitcoin'): 1,
#  ('bitcoin', 'v'): 1,
#  ('v', 'ethereumgetty'): 1,
#  ('ethereumgetty', 'images'): 1,
#  ('images', 'asiapacbitcoin'): 1,
#  ('asiapacbitcoin', 'long'): 1,
#  ('long', 'dominant'): 1,
#  ('dominant', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'recently'): 1,
#  ('recently', 'ethereums'): 1,
#  ('ethereums', 'native'): 1,
#  ('native', 'token'): 1,
#  ('token', 'ether'): 1,
#  ('ether', 'emerged'): 1,
#  ('emerged', 'clear'): 1,
#  ('clear', 'number'): 1,
#  ('number', 'two'): 1,
#  ('two', 'representation'): 1,
#  ('reutersdado', 'ruvicillustrationbitcoin'): 1,
#  ('ruvicillustrationbitcoin', 'ethereum'): 1,
#  ('ethereum', 'two'): 1,
#  ('two', 'largest'): 1,
#  ('largest', 'cry'): 1,
#  ('cry', 'representation'): 1,
#  ('currency', 'bitcoin'): 6,
#  ('bitcoin', 'seen'): 3,
#  ('taken', 'march'): 2,
#  ('march', 'reutersdado'): 2,
#  ('reutersdado', 'ruvicillustrationthe'): 1,
#  ('ruvicillustrationthe', 'sampp'): 1,
#  ('new', 'cry'): 1,
#  ('cry', 'cryptocurrency'): 1,
#  ('high', 'wednesday'): 1,
#  ('wednesday', 'adding'): 1,
#  ('adding', 'recent'): 1,
#  ('recent', 'surge'): 2,
#  ('surge', 'back'): 1,
#  ('back', 'broader'): 1,
#  ('broader', 'runup'): 1,
#  ('runup', 'decentralised'): 1,
#  ('decentralised', 'finance'): 1,
#  ('finance', 'application'): 1,
#  ('application', 'increasing'): 1,
#  ('increasing', 'institutional'): 1,
#  ('institutional', 'interest'): 1,
#  ('interest', 'cryptocurr'): 1,
#  ('cryptocurr', 'article'): 1,
#  ('processcryptocurrencies', 'gaining'): 1,
#  ('gaining', 'ground'): 1,
#  ('ground', 'world'): 1,
#  ('world', 'investment'): 1,
#  ('investment', 'cryptocurrency'): 1,
#  ('ether', 'native'): 2,
#  ('native', 'ethereum'): 2,
#  ('ethereum', 'blockchain'): 3,
#  ('blockchain', 'hit'): 2,
#  ('hit', 'new'): 2,
#  ('new', 'alltime'): 2,
#  ('alltime', 'high'): 5,
#  ('monday', 'standout'): 2,
#  ('standout', 'performance'): 2,
#  ('performance', 'outpaced'): 2,
#  ('outpaced', 'rival'): 2,
#  ('rival', 'currency'): 2,
#  ('currency', 'bitcoins'): 2,
#  ('bitcoins', 'gain'): 2,
#  ('gain', 'far'): 1,
#  ('far', 'yeart'): 1,
#  ('yeart', 'cryptocurrencyethereum'): 1,
#  ('cryptocurrencyethereum', 'hit'): 1,
#  ('hit', 'alltime'): 2,
#  ('monday', 'surpassing'): 1,
#  ('surpassing', 'mark'): 1,
#  ('mark', 'beating'): 1,
#  ('beating', 'bitcoins'): 1,
#  ('bitcoins', 'yeartodate'): 1,
#  ('yeartodate', 'gain'): 1,
#  ('gain', 'according'): 1,
#  ('according', 'toreutersether'): 1,
#  ('toreutersether', 'token'): 1,
#  ('token', 'used'): 1,
#  ('used', 'ethereum'): 1,
#  ('blockchain', 'j'): 1,
#  ('j', 'representations'): 1,
#  ('representations', 'virtual'): 2,
#  ('bitcoin', 'placed'): 2,
#  ('placed', 'us'): 2,
#  ('us', 'dollar'): 2,
#  ('dollar', 'banknote'): 2,
#  ('banknote', 'illustration'): 2,
#  ('taken', 'may'): 2,
#  ('may', 'reutersdado'): 2,
#  ('reutersdado', 'ruvicfile'): 1,
#  ('ruvicfile', 'photobitcoin'): 1,
#  ('photobitcoin', 'hit'): 1,
#  ('record', 'outflow'): 1,
#  ('outflow', 'last'): 1,
#  ('last', 'investo'): 1,
#  ('investo', 'bitcoin'): 1,
#  ('ethereum', 'posted'): 1,
#  ('posted', 'largest'): 1,
#  ('largest', 'oneday'): 1,
#  ('oneday', 'drop'): 1,
#  ('drop', 'since'): 1,
#  ('since', 'march'): 1,
#  ('march', 'last'): 1,
#  ('last', 'year'): 1,
#  ('year', 'wednesday'): 1,
#  ('wednesday', 'loss'): 1,
#  ('loss', 'market'): 1,
#  ('market', 'capitalization'): 2,
#  ('capitalization', 'entire'): 1,
#  ('entire', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'sector'): 1,
#  ('sector', 'approaching'): 1,
#  ('approaching', 'trillionthe'): 1,
#  ('trillionthe', 'ethereum'): 1,
#  ('ethereum', 'reduce'): 1,
#  ('reduce', 'energy'): 1,
#  ('energy', 'consumption'): 1,
#  ('consumption', 'following'): 1,
#  ('following', 'transition'): 1,
#  ('transition', 'proofofstake'): 1,
#  ('proofofstake', 'according'): 1,
#  ('according', 'new'): 1,
#  ('new', 'blog'): 1,
#  ('blog', 'post'): 1,
#  ('post', 'carl'): 1,
#  ('carl', 'beekhuizen'): 1,
#  ('beekhuizen', 'ethereum'): 1,
#  ('ethereum', 'foundation'): 1,
#  ('foundation', 'beekhuizen'): 1,
#  ('beekhuizen', 'estimated'): 1,
#  ('estimated', 'th'): 1,
#  ('th', 'latest'): 1,
#  ('latest', 'toenail'): 1,
#  ('toenail', 'clipping'): 1,
#  ('clipping', 'theyre'): 1,
#  ('theyre', 'probably'): 1,
#  ('probably', 'worth'): 1,
#  ('worth', 'one'): 1,
#  ('one', 'hundred'): 1,
#  ('billion', 'trillion'): 1,
#  ('trillion', 'dollar'): 2,
#  ('dollar', 'time'): 1,
#  ('time', 'writingor'): 1,
#  ('writingor', 'donate'): 1,
#  ('donate', 'actual'): 1,
#  ('actual', 'money'): 1,
#  ('money', 'appear'): 1,
#  ('appear', 'credible'): 1,
#  ('credible', 'reuters'): 1,
#  ('reuters', 'staffmay'): 1,
#  ('staffmay', 'reuters'): 1,
#  ('reuters', 'sampp'): 1,
#  ('indices', 'division'): 1,
#  ('division', 'financial'): 1,
#  ('financial', 'data'): 1,
#  ('data', 'provider'): 1,
#  ('provider', 'sampp'): 1,
#  ('sampp', 'global'): 1,
#  ('global', 'inc'): 1,
#  ('inc', 'said'): 1,
#  ('tuesday', 'launched'): 1,
#  ('new', 'series'): 1,
#  ('series', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'indicest'): 1,
#  ('indicest', 'dado'): 1,
#  ('dado', 'ruvicreuterscryptocurrency'): 1,
#  ('ruvicreuterscryptocurrency', 'ether'): 1,
#  ('gain', 'reuters'): 1,
#  ('reutersdado', 'ruvicillustrationreuters'): 1,
#  ('ruvicillustrationreuters', 'representation'): 1,
#  ('ether', 'broke'): 1,
#  ('broke', 'past'): 1,
#  ('past', 'biotech'): 1,
#  ('biotech', 'company'): 1,
#  ('company', 'spent'): 1,
#  ('spent', 'year'): 1,
#  ('year', 'researching'): 1,
#  ('researching', 'supplement'): 1,
#  ('supplement', 'increase'): 1,
#  ('increase', 'human'): 1,
#  ('human', 'longevity'): 1,
#  ('longevity', 'plan'): 1,
#  ('plan', 'launch'): 1,
#  ('launch', 'supplement'): 1,
#  ('supplement', 'later'): 1,
#  ('later', 'year'): 1,
#  ('year', 'longevica'): 1,
#  ('longevica', 'say'): 1,
#  ('say', 'attracted'): 1,
#  ('attracted', 'total'): 1,
#  ('total', 'million'): 1,
#  ('million', 'dado'): 1,
#  ('dado', 'ruvicreutersether'): 3,
#  ('ruvicreutersether', 'digital'): 1,
#  ('digital', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'tied'): 1,
#  ('tied', 'ethereum'): 1,
#  ('ethereum', 'network'): 1,
#  ('network', 'soared'): 1,
#  ('soared', 'new'): 1,
#  ('new', 'record'): 2,
#  ('record', 'monday'): 1,
#  ('monday', 'hitting'): 1,
#  ('hitting', 'high'): 1,
#  ('high', 'digital'): 1,
#  ('currency', 'often'): 1,
#  ('often', 'use'): 1,
#  ('use', 'dado'): 1,
#  ('ruvicreutersether', 'recorded'): 1,
#  ('recorded', 'biggest'): 1,
#  ('biggest', 'oneday'): 1,
#  ('oneday', 'gain'): 1,
#  ('gain', 'two'): 1,
#  ('two', 'year'): 1,
#  ('year', 'monday'): 1,
#  ('monday', 'world'): 1,
#  ('world', 'secondlargest'): 1,
#  ('secondlargest', 'currency'): 1,
#  ('currency', 'smashed'): 1,
#  ('smashed', 'past'): 1,
#  ('past', 'first'): 1,
#  ('first', 'timeethereums'): 1,
#  ('timeethereums', 'digital'): 1,
#  ('digital', 'token'): 1,
#  ('token', 'rose'): 1,
#  ('rose', 'article'): 1,
#  ('due', 'processthis'): 1,
#  ('processthis', 'world'): 1,
#  ('world', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'experienced'): 1,
#  ('experienced', 'severe'): 1,
#  ('severe', 'collapse'): 1,
#  ('collapse', 'losing'): 1,
#  ('losing', 'yuriko'): 1,
#  ('yuriko', 'nakaogetty'): 1,
#  ('nakaogetty', 'imagesinvestors'): 1,
#  ('imagesinvestors', 'add'): 1,
#  ('add', 'bitcoin'): 1,
#  ('ethereum', 'portfolio'): 1,
#  ('portfolio', 'new'): 1,
#  ('index', 'available'): 1,
#  ('available', 'wall'): 1,
#  ('wall', 'street'): 2,
#  ('street', 'trading'): 1,
#  ('trading', 'floorssampp'): 1,
#  ('floorssampp', 'dow'): 1,
#  ('jones', 'tuesday'): 1,
#  ('tuesday', 'announc'): 1,
#  ('announc', 'kr'): 1,
#  ('kr', 'one'): 1,
#  ('one', 'europes'): 1,
#  ('europes', 'leading'): 1,
#  ('leading', 'blockchain'): 1,
#  ('blockchain', 'digital'): 1,
#  ('digital', 'asset'): 4,
#  ('asset', 'venture'): 1,
#  ('venture', 'capital'): 2,
#  ('capital', 'firm'): 1,
#  ('firm', 'firm'): 1,
#  ('firm', 'listed'): 1,
#  ('listed', 'aquis'): 1,
#  ('aquis', 'stock'): 1,
#  ('stock', 'exchange'): 1,
#  ('exchange', 'since'): 1,
#  ('since', 'invested'): 1,
#  ('invested', 'crypto'): 1,
#  ('crypto', 'project'): 1,
#  ('project', 'ethereum'): 1,
#  ('ethereum', 'pol'): 1,
#  ('pol', 'hello'): 1,
#  ('hello', 'friend'): 1,
#  ('friend', 'welcome'): 1,
#  ('welcome', 'back'): 1,
#  ('back', 'reviewlast'): 1,
#  ('reviewlast', 'wrote'): 1,
#  ('wrote', 'facebooks'): 1,
#  ('facebooks', 'neverending'): 1,
#  ('neverending', 'trump'): 1,
#  ('trump', 'problem'): 1,
#  ('problem', 'im'): 1,
#  ('im', 'looking'): 1,
#  ('looking', 'elon'): 1,
#  ('elon', 'musks'): 3,
#  ('musks', 'wild'): 1,
#  ('wild', 'whipping'): 1,
#  ('whipping', 'crypto'): 1,
#  ('crypto', 'marketsif'): 1,
#  ('marketsif', 'trend'): 1,
#  ('trend', 'outrageous'): 1,
#  ('outrageous', 'nft'): 1,
#  ('nft', 'auction'): 1,
#  ('auction', 'sale'): 1,
#  ('sale', 'continue'): 1,
#  ('continue', 'sale'): 1,
#  ('sale', 'disaster'): 1,
#  ('disaster', 'girl'): 2,
#  ('girl', 'nft'): 1,
#  ('nft', 'went'): 1,
#  ('went', 'auction'): 1,
#  ('auction', 'hosted'): 1,
#  ('hosted', 'foundationeven'): 1,
#  ('foundationeven', 'youre'): 1,
#  ('youre', 'unaware'): 1,
#  ('unaware', 'disaster'): 1,
#  ('girl', 'getty'): 1,
#  ('getty', 'imagesjohn'): 2,
#  ('imagesjohn', 'phillipsthe'): 1,
#  ('phillipsthe', 'yearold'): 1,
#  ('yearold', 'cocreator'): 1,
#  ('cocreator', 'ethereum'): 1,
#  ('ethereum', 'vitalik'): 1,
#  ('buterin', 'world'): 1,
#  ('world', 'youngest'): 1,
#  ('youngest', 'crypto'): 1,
#  ('crypto', 'billionaire'): 1,
#  ('billionaire', 'yeartodate'): 1,
#  ('yeartodate', 'surge'): 1,
#  ('surge', 'price'): 1,
#  ('price', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'dado'): 1,
#  ('ruvicreutersether', 'spiked'): 1,
#  ('spiked', 'thursday'): 1,
#  ('thursday', 'new'): 1,
#  ('high', 'pushing'): 1,
#  ('pushing', 'market'): 1,
#  ('capitalization', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'near'): 1,
#  ('near', 'billion'): 1,
#  ('billion', 'first'): 1,
#  ('first', 'timethe'): 1,
#  ('timethe', 'seco'): 1,
#  ('seco', 'reuters'): 1,
#  ('reuters', 'staffapril'): 1,
#  ('staffapril', 'reuters'): 1,
#  ('reuters', 'bitcoin'): 2,
#  ('bitcoin', 'dropped'): 3,
#  ('dropped', 'saturday'): 1,
#  ('saturday', 'losing'): 1,
#  ('losing', 'previous'): 1,
#  ('previous', 'closebitcoin'): 2,
#  ('closebitcoin', 'world'): 2,
#  ('world', 'biggest'): 2,
#  ('biggest', 'bestknown'): 2,
#  ('bestknown', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'anthony'): 1,
#  ('anthony', 'di'): 2,
#  ('di', 'ionio'): 1,
#  ('ionio', 'cofounder'): 1,
#  ('cofounder', 'ethereumphoto'): 1,
#  ('ethereumphoto', 'decentralethereum'): 1,
#  ('decentralethereum', 'cofounder'): 1,
#  ('cofounder', 'anthony'): 1,
#  ('di', 'iorio'): 1,
#  ('iorio', 'said'): 1,
#  ('said', 'think'): 1,
#  ('think', 'market'): 1,
#  ('market', 'nonfungible'): 1,
#  ('nonfungible', 'token'): 1,
#  ('token', 'become'): 1,
#  ('become', 'saturated'): 1,
#  ('saturated', 'space'): 1,
#  ('space', 'gained'): 1,
#  ('gained', 'preamble'): 1,
#  ('preamble', 'energy'): 1,
#  ('energy', 'power'): 1,
#  ('power', 'unit'): 1,
#  ('unit', 'energy'): 1,
#  ('energy', 'well'): 1,
#  ('well', 'use'): 1,
#  ('use', 'post'): 1,
#  ('post', 'kilowatthour'): 1,
#  ('kilowatthour', 'kwh'): 1,
#  ('kwh', 'quantity'): 1,
#  ('quantity', 'called'): 1,
#  ('called', 'one'): 1,
#  ('one', 'unit'): 1,
#  ('unit', 'electricity'): 1,
#  ('electricity', 'bill'): 1,
#  ('bill', 'cost'): 1,
#  ('cost', 'domestic'): 1,
#  ('domestic', 'user'): 1,
#  ('user', 'cent'): 1,
#  ('cent', 'prices'): 1,
#  ('prices', 'bitcoin'): 1,
#  ('bitcoin', 'cryptocurrencies'): 2,
#  ('cryptocurrencies', 'boomed'): 1,
#  ('boomed', 'year'): 1,
#  ('year', 'part'): 1,
#  ('part', 'growing'): 1,
#  ('growing', 'acceptance'): 1,
#  ('acceptance', 'digital'): 1,
#  ('asset', 'wall'): 1,
#  ('street', 'corporate'): 1,
#  ('corporate', 'america'): 1,
#  ('america', 'broader'): 1,
#  ('broader', 'correction'): 1,
#  ('correction', 'market'): 1,
#  ('market', 'appea'): 1,
#  ('appea', 'mastercard'): 1,
#  ('mastercard', 'bny'): 1,
#  ('bny', 'mellon'): 1,
#  ('mellon', 'warmed'): 1,
#  ('warmed', 'bitcoin'): 1,
#  ('bitcoin', 'thursday'): 1,
#  ('thursday', 'supporting'): 1,
#  ('supporting', 'xrp'): 1,
#  ('xrp', 'ether'): 1,
#  ('ether', 'cryptocurrenciesyuriko'): 1,
#  ('cryptocurrenciesyuriko', 'nakaogetty'): 1,
#  ('nakaogetty', 'imagesbitcoin'): 1,
#  ('imagesbitcoin', 'struggling'): 1,
#  ('struggling', 'tumbling'): 1,
#  ('tumbling', 'level'): 1,
#  ('level', 'april'): 1,
#  ('readthis', 'story'): 1,
#  ('appeared', 'stocknewsone'): 1,
#  ('stocknewsone', 'biggest'): 1,
#  ('biggest', 'story'): 1,
#  ('story', 'year'): 1,
#  ('year', 'rise'): 1,
#  ('rise', 'crypto'): 1,
#  ('crypto', 'currency'): 1,
#  ('ethereum', 'dogecoin'): 1,
#  ('dogecoin', 'coinba'): 1,
#  ('coinba', 'updates'): 1,
#  ('updates', 'sourcing'): 1,
#  ('sourcing', 'add'): 1,
#  ('add', 'contextapril'): 1,
#  ('contextapril', 'reuters'): 1,
#  ('reuters', 'european'): 1,
#  ('european', 'investment'): 1,
#  ('investment', 'bank'): 2,
#  ('bank', 'eib'): 1,
#  ('eib', 'raised'): 1,
#  ('raised', 'million'): 2,
#  ('million', 'euro'): 1,
#  ('euro', 'million'): 1,
#  ('million', 'twoyear'): 1,
#  ('twoyear', 'digital'): 1,
#  ('digital', 'bond'): 1,
#  ('bond', 'issue'): 1,
#  ('issue', 'spokesperson'): 1,
#  ('spokesperson', 'told'): 1,
#  ('told', 'reuters'): 1,
#  ('reuters', 'sudden'): 1,
#  ('sudden', 'unexpected'): 1,
#  ('unexpected', 'death'): 1,
#  ('death', 'millions'): 1,
#  ('millions', 'dollar'): 1,
#  ('dollar', 'worth'): 1,
#  ('worth', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'gone'): 1,
#  ('gone', 'amateur'): 1,
#  ('amateur', 'detective'): 1,
#  ('detective', 'poring'): 1,
#  ('poring', 'digital'): 1,
#  ('digital', 'puzzle'): 1,
#  ('puzzle', 'piece'): 1,
#  ('piece', 'desperate'): 1,
#  ('desperate', 'bid'): 1,
#  ('bid', 'reclaim'): 1,
#  ('reclaim', 'whats'): 1,
#  ('whats', 'theirsif'): 1,
#  ('theirsif', 'paid'): 1,
#  ('paid', 'attent'): 1,
#  ('attent', 'jaap'): 1,
#  ('jaap', 'arriensnurphoto'): 1,
#  ('arriensnurphoto', 'via'): 1,
#  ('via', 'getty'): 1,
#  ('getty', 'imagescryptocurrency'): 1,
#  ('imagescryptocurrency', 'linkedstocks'): 1,
#  ('linkedstocks', 'plummeted'): 1,
#  ('plummeted', 'wednesday'): 2,
#  ('wednesday', 'amid'): 1,
#  ('amid', 'massive'): 1,
#  ('massive', 'selloff'): 2,
#  ('selloff', 'crypto'): 1,
#  ('crypto', 'leader'): 1,
#  ('leader', 'bitcoin'): 1,
#  ('bitcoin', 'ethereumshares'): 1,
#  ('ethereumshares', 'cryptocurrency'): 1,
#  ('exchange', 'coin'): 1,
#  ('coin', 'new'): 1,
#  ('york', 'cnnon'): 1,
#  ('cnnon', 'morning'): 1,
#  ('morning', 'april'): 1,
#  ('april', 'two'): 1,
#  ('two', 'brother'): 1,
#  ('brother', 'westchester'): 1,
#  ('westchester', 'new'): 1,
#  ('york', 'woke'): 1,
#  ('woke', 'learn'): 1,
#  ('learn', 'become'): 1,
#  ('become', 'millionaire'): 1,
#  ('millionaire', 'overnight'): 1,
#  ('overnight', 'thanks'): 1,
#  ('thanks', 'unlikely'): 1,
#  ('unlikely', 'wager'): 1,
#  ('wager', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'wa'): 1,
#  ('wa', 'crypto'): 1,
#  ('crypto', 'crash'): 1,
#  ('crash', 'past'): 1,
#  ('past', 'day'): 1,
#  ('day', 'shocked'): 1,
#  ('shocked', 'investor'): 1,
#  ('investor', 'around'): 1,
#  ('around', 'world'): 1,
#  ('world', 'vitalik'): 1,
#  ('buterin', 'isnt'): 1,
#  ('isnt', 'among'): 1,
#  ('among', 'even'): 1,
#  ('even', 'though'): 1,
#  ('though', 'meltdown'): 1,
#  ('meltdown', 'wiped'): 1,
#  ('wiped', 'huge'): 1,
#  ('huge', 'chunk'): 1,
#  ('chunk', 'personal'): 1,
#  ('personal', 'wealthin'): 1,
#  ('wealthin', 'fact'): 1,
#  ('fact', 'representation'): 1,
#  ('seen', 'motherboard'): 1,
#  ('motherboard', 'picture'): 1,
#  ('picture', 'illustration'): 1,
#  ('taken', 'april'): 1,
#  ('april', 'reutersdado'): 1,
#  ('reutersdado', 'ruvicillustrationfile'): 1,
#  ('ruvicillustrationfile', 'photofile'): 1,
#  ('photofile', 'photobitcoin'): 1,
#  ('photobitcoin', 'dropped'): 1,
#  ('dropped', 'logo'): 1,
#  ('logo', 'bitcoin'): 1,
#  ('bitcoin', 'digital'): 1,
#  ('currency', 'seen'): 1,
#  ('seen', 'shop'): 1,
#  ('shop', 'marseille'): 1,
#  ('marseille', 'france'): 1,
#  ('france', 'february'): 1,
#  ('february', 'reuterseric'): 1,
#  ('reuterseric', 'gaillardbitcoin'): 1,
#  ('gaillardbitcoin', 'rose'): 1,
#  ('rose', 'friday'): 1,
#  ('friday', 'adding'): 1,
#  ('adding', 'previous'): 2,
#  ('previous', 'cl'): 1,
#  ('cl', 'representations'): 1,
#  ('reutersdado', 'ruvicbitcoin'): 1,
#  ('ruvicbitcoin', 'rose'): 1,
#  ('rose', 'gmt'): 2,
#  ('gmt', 'wednesday'): 1,
#  ('wednesday', 'ad'): 1,
#  ('ad', 'bitcoin'): 1,
#  ('bitcoin', 'rose'): 1,
#  ('gmt', 'sunday'): 1,
#  ('sunday', 'adding'): 1,
#  ('cryptocurrency', 'year'): 1,
#  ('year', 'low'): 1,
#  ('low', 'enlarge'): 1,
#  ('enlarge', 'coming'): 1,
#  ('coming', 'soon'): 1,
#  ('soon', 'nearly'): 1,
#  ('nearly', 'identical'): 1,
#  ('identical', 'version'): 1,
#  ('version', 'gpus'): 1,
#  ('gpus', 'lhr'): 1,
#  ('lhr', 'logosand'): 1,
#  ('logosand', 'new'): 1,
#  ('new', 'measure'): 1,
#  ('measure', 'reduce'): 1,
#  ('reduce', 'mining'): 1,
#  ('mining', 'hash'): 1,
#  ('hash', 'rate'): 2,
#  ('rate', 'poster'): 1,
#  ('poster', 'participatingnvidias'): 1,
#  ('participatingnvidias', 'geforce'): 1,
#  ('geforce', 'rtx'): 2,
#  ('rtx', 'br'): 1,
#  ('br', 'dollar'): 1,
#  ('dollar', 'recovered'): 1,
#  ('recovered', 'nineweek'): 1,
#  ('nineweek', 'low'): 1,
#  ('low', 'thursday'): 1,
#  ('thursday', 'lifted'): 1,
#  ('lifted', 'rise'): 1,
#  ('rise', 'us'): 1,
#  ('us', 'treasury'): 1,
#  ('treasury', 'yield'): 1,
#  ('yield', 'government'): 1,
#  ('government', 'reported'): 1,
#  ('reported', 'strong'): 1,
#  ('strong', 'economic'): 1,
#  ('economic', 'growth'): 1,
#  ('growth', 'first'): 1,
#  ('first', 'quarter'): 1,
#  ('quarter', 'improvement'): 1,
#  ('improvement', 'new'): 1,
#  ('new', 'jo'): 1,
#  ('jo', 'staking'): 1,
#  ('staking', 'need'): 1,
#  ('need', 'become'): 1,
#  ('become', 'validator'): 1,
#  ('validator', 'proofofstake'): 1,
#  ('proofofstake', 'system'): 1,
#  ('system', 'consensus'): 1,
#  ('consensus', 'mechanism'): 1,
#  ('mechanism', 'going'): 1,
#  ('going', 'replace'): 1,
#  ...}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
token_count(btc_t, 10)
# Out:
# [('bitcoin', 73),
#  ('tesla', 32),
#  ('elon', 32),
#  ('cryptocurrency', 20),
#  ('reuters', 20),
#  ('currency', 19),
#  ('company', 16),
#  ('said', 16),
#  ('seen', 14),
#  ('inc', 13)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(eth_t, 10)
# Out:
# [('bitcoin', 45),
#  ('ethereum', 30),
#  ('cryptocurrency', 24),
#  ('currency', 23),
#  ('crypto', 17),
#  ('new', 16),
#  ('reuters', 16),
#  ('digital', 16),
#  ('monday', 15),
#  ('year', 15)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
btc_cloud = WordCloud().generate(' '.join(btc_t))
plt.title("BTC Word Cloud", fontsize = 50, fontweight = 'bold')
plt.imshow(btc_cloud)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
eth_cloud = WordCloud().generate(' '.join(eth_t))
plt.title("ETH Word Cloud", fontsize = 50, fontweight = 'bold')
plt.imshow(eth_cloud)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_text = ' '.join(btc_df['text'])
btc_text
# Out:
# 'Just weeks after Tesla started accepting Bitcoin as currency for cars, Elon Musk revealed in a tweet that it will "suspend" the effort. According to the release (Tesla does not appear to have a funct… [+768 chars] Shares of Square are up more than 6% today after the American fintech company reported a staggering $5.06 billion in revenue in its Q1 2021 earnings report, far ahead of an expected tally of $3.36 bi… [+2045 chars] Tesla’s relationship with bitcoin is not a dalliance, according to the comments made by the company’s CFO and dubbed “master of coin” Zach Kirkhorn during an earnings call Monday. Instead, the compan… [+3073 chars] Image: Tesla\r\n\n \n\n Tesla has stopped accepting bitcoin as payment for its cars out of concern that it will contribute to greater consumption of fossil fuels, according to a statement CEO Elon Musk tw… [+853 chars] Cryptocurrency prices continued to tumble Friday with Bitcoin leading the charge, with prices for the internet currency dipping below $50,000 for the first time since early March.\r\nBitcoin is down ro… [+1222 chars] Mark Zuckerberg posted a picture of his two, frankly adorable, goats noting their names are Max and Bitcoin.\r\nAnd to that I say: OK then.\xa0\r\nHere\'s the post in question.\xa0\r\nLook at those cute little go… [+1482 chars] Illustration by Alex Castro / The Verge\r\n\n \n\n Cryptocurrency exchange Coinbase is experiencing a “partial” outage this morning for its entire site and application. Additionally, both Coinbase and Bin… [+1307 chars] Last week, whenElon Musk tweeted that he had spoken with the team of Doge developers about how to make the coin more efficient, the impact was predictable: It sent Dogecoin to the moon. It was just t… [+3313 chars] Tesla CEO Elon Musk has changed his stance on cryptocurrency.\r\nBack in March, Musk announced Tesla was accepting Bitcoin for its electric cars. Earlier this year the EV company even bought $1.5 billi… [+1308 chars] image copyrightGetty Images\r\nimage captionElon Musk\'s Tesla has seen a jump in profits\r\nTesla has posted first quarter profits of $438m (£315m) bolstered by sales of Bitcoin and environmental credits… [+2702 chars] Earth Day is prime time for brands and people to promote their pre-existing products to the masses, swaddled up in a green package. So perhaps its no surprise that area shaman Jack Dorsey and meme en… [+4711 chars] That love affair between Elon Musk and Bitcoin? It\'s just become complicated.\xa0\r\nIt\'s been a rough couple of days in crypto world, with prices of most major crypto assets plummeting Bitcoin, in partic… [+6347 chars] Three years after its inception, crypto financial service provider Babel Finance is racking up fundings and partnerships from major institutional investors. The startup said Monday that it has closed… [+2610 chars] Bitcoin, Ethereum and a host of Altcoins suffered massive drops Tuesday night and Wednesday morning, erasing months of gains and hundreds of billions in market cap. The overall crypto market shrunk m… [+1182 chars] New York (CNN Business)Bitcoin prices continued their rebound Saturday, rising about 6% to nearly $58,000. But the world\'s largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars] Now isn\'t the greatest time to be a cryptocurrency trader. Coinbase suffered an hours-long outage this morning (May 19th) that hindered transactions on the exchange. The company had pinpointed the ma… [+909 chars] When it comes to ransomware, you don\'t always get what you pay for.\xa0\r\nColonial Pipeline, which operates more than 5,500 miles of fuel pipelines in the United States, found that out the hard way this … [+1855 chars] The two founders of Crusoe Energy think they may have a solution to two of the largest problems facing the planet today — the increasing energy footprint of the tech industry and the greenhouse gas e… [+7655 chars] Elon Musk really, REALLY likes Dogecoin.\xa0\r\nAfter endlessly shilling the joke cryp ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc_btc = nlp(btc_text)

# Add a title to the document
# YOUR CODE HERE!doc.user_data["title"] = "BITCOIN NER"

doc_btc.user_data["title"] = "BTC NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc_btc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BTC NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Just weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  started accepting
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as currency for cars,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  revealed in a tweet that it will &quot;suspend&quot; the effort. According to the release (Tesla does not appear to have a funct… [+768 chars] Shares of Square are up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  fintech company reported a staggering
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $5.06 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in revenue in its Q1
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  earnings report, far ahead of an expected tally of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.36
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  bi… [+2045 chars] Tesla’s relationship with bitcoin is not a dalliance, according to the comments made by the company’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CFO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and dubbed “master of coin”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zach Kirkhorn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  during an earnings call
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br> </br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has stopped accepting bitcoin as payment for its cars out of concern that it will contribute to greater consumption of fossil fuels, according to a statement CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tw… [+853 chars] Cryptocurrency prices continued to tumble
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  leading the charge, with prices for the internet currency dipping below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is down ro… [+1222 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  posted a picture of his
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0

# %%
# List all Entities
# YOUR CODE HERE!
for ent in doc_btc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Just weeks DATE
# Tesla ORG
# Bitcoin PERSON
# Elon Musk PERSON
# more than 6% PERCENT
# today DATE
# American NORP
# $5.06 billion MONEY
# 2021 DATE
# 3.36 MONEY
# CFO ORG
# Zach Kirkhorn PERSON
# Monday DATE
# Tesla ORG
# Elon Musk PERSON
# Friday DATE
# Bitcoin PERSON
# 50,000 MONEY
# first ORDINAL
# early March DATE
# Bitcoin PERSON
# Mark Zuckerberg PERSON
# two CARDINAL
# Max PERSON
# Bitcoin PERSON
# Alex Castro PERSON
# The Verge
#
#
#
#  Cryptocurrency ORG
# Coinbase PERSON
# this morning TIME
# Coinbase PERSON
# Bin PERSON
# Last week DATE
# Musk PERSON
# Dogecoin GPE
# Elon Musk PERSON
# March DATE
# Musk PERSON
# Tesla PERSON
# Earlier this year DATE
# EV ORG
# 1.5 MONEY
# Musk PERSON
# Tesla PERSON
# Tesla PERSON
# first quarter DATE
# $438m MONEY
# 315 MONEY
# Bitcoin ORG
# ] Earth Day EVENT
# Jack Dorsey PERSON
# Elon Musk PERSON
# Bitcoin PERSON
# Bitcoin PERSON
# Three years DATE
# Babel Finance ORG
# Monday DATE
# Altcoins PERSON
# Tuesday night TIME
# Wednesday DATE
# morning TIME
# months DATE
# hundreds of billions MONEY
# New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# hours-long TIME
# this morning TIME
# May 19th DATE
# more than 5,500 miles QUANTITY
# the United States GPE
# two CARDINAL
# Crusoe Energy ORG
# two CARDINAL
# today DATE
# Elon Musk PERSON
# Dogecoin GPE
# Twitter PRODUCT
# Dogecoin GPE
# Last week DATE
# Trump ORG
# This week DATE
# Elon Musk’s ORG
# Australian NORP
# London High Court ORG
# 16 CARDINAL
# around 4 billion pounds MONEY
# about $50,000 MONEY
# Asian NORP
# Thursday DATE
# as much as 17% PERCENT
# Elon Musk PERSON
# Tesla Inc PERSON
# Bitcoin PERSON
# U.S. GPE
# January 8, 2021 DATE
# Dado Ruvic/File PhotoTesla Inc PERSON
# Reuters ORG
# May 12 DATE
# Reuters ORG
# Elon Musk PERSON
# Coinbase ORG
# Dogecoin GPE
# Jack Dorsey PERSON
# Twitter PRODUCT
# Wednesday DATE
# Elon Musk PERSON
# BBC ORG
# Coinswitch Kuber PERSON
# India GPE
# Thursday DATE
# $25 million MONEY
# Indi GPE
# Elon Musk PERSON
# Bitcoin ORG
# Bitcoin PERSON
# Reuters ORG
# Santa Clarita GPE
# California GPE
# U.S. GPE
# October 2, 2019 DATE
# Mike Blake
#  PERSON
# Reuters ORG
# $27 million MONEY
# Bitcoin PERSON
# Marseille GPE
# France GPE
# February 7, 2021 DATE
# Eric GaillardBitcoin PERSON
# 6.54% PERCENT
# 57,098.08 MONEY
# Friday DATE
# 3,504.11 MONEY
# Reuters ORG
# April 24 DATE
# Reuters ORG
# 1.77% PERCENT
# 50,269.9 MONEY
# Saturday DATE
# 906.75 MONEY
# Bitcoin PERSON
# 22.5 CARDINAL
# Bitcoin PERSON
# April 24, 2020 DATE
# 1.77% PERCENT
# Bitcoin PERSON
# U.S. Dollar ORG
# May 26, 2020 DATE
# 6.8% PERCENT
# $56,852.03 MONEY
# 1000 CARDINAL
# GMT ORG
# Wednesday DATE
# WASHINGTON GPE
# Reuters Breakingviews ORG
# U.S. GPE
# Bitcoins PERSON
# Monday DATE
# February DATE
# Elon Musk PERSON
# Tesla PERSON
# the weekend DATE
# 24, 2021 DATE
# more than 25% PERCENT
# Millions of dollars MONEY
# Elon Musk PERSON
# Bitcoins PERSON
# a few month DATE
# Elon Musk PERSON
# Bitcoin PERSON
# The Tesla Inc PERSON
# U.S. GPE
# first ORDINAL
# Bitcoin PERSON
# Bitcoin PERSON
# Reuters ORG
# May 11 DATE
# Reuters ORG
# Peter Thiel-backed PERSON
# U.S. GPE
# Palantir Technologies Inc ORG
# Tuesday DATE
# three-month DATE
# Monday DATE
# Elon Musk's PERSON
# the weekend DATE
# Bitcoin PERSON
# three-month DATE
# Monday DATE
# Elon Musk's PERSON
# Reuters ORG
# SINGAPORE PERSON
# Reuters ORG
# three-month DATE
# Monday DATE
# Elon Musks PERSON
# the weekend DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Bitcoin ORG
# 45,000 MONEY
# Sunday DATE
# Elon Musk PERSON
# Tesla ORG
# Elon Musk PERSON
# Bitcoin PERSON
# Tesla PERSON
# first quarter DATE
# hundreds CARDINAL
# US GPE
# this year DATE
# CNBC ORG
# Wednesday DATE
# NYDIG ORG
# Fidelity Nati PERSON
# 27, 2021 DATE
# Entrepreneur ORG
# Bitcoin PERSON
# over 9% PERCENT
# 50,000 MONEY
# CoinDesk ORG
# Monday DATE
# 3 p.m. PDT TIME
# Daily Crunch WORK_OF_ART
# Bitcoin PERSON
# the Bitcoin Center New York City ORG
# New York's GPE
# July 28, 2015 DATE
# REUTERS ORG
# Brendan McDermidU.S. PERSON
# Tuesday DATE
# Roman Sterlingov PERSON
# Groot GPE
# Daily Crunch WORK_OF_ART
# April 23, 2021 DATE
# Meet Disney Imagineering ORG
# Elon Musk PERSON
# About a quarter DATE
# Bitcoins GPE
# the span of a week DATE
# Bitcoin ORG
# as much as 29% PERCENT
# Wednesday DATE
# the China Banking Association ORG
# Tom Brady PERSON
# Twitter PRODUCT
# Reuters ORG
# May 6 DATE
# Reuters ORG
# second ORDINAL
# Bitcoin PERSON
# Thursday DATE
# 3,591.65 MONEY
# the Bitstamp Exchange ORG
# about 3 CARDINAL
# LONDON GPE
# May 13 DATE
# Reuters ORG
# Elon Musk PERSON
# Tesla PERSON
# Musk PERSON
# Reuters ORG
# May 13 DATE
# Reuters ORG
# Elon Musks PERSON
# Some Tes PERSON
# Greenidge Generation Holdings Inc ORG
# Friday DATE
# New York GPE
# June 1 DATE
# Medium EVENT
# Tusk PERSON
# Yangs PERSON
# David J. Phillip PERSON
# Mark Cuban PERSON
# Wednesday DATE
# Elon Musk PERSON
# Tesla PERSON
# Goldman Sachs Group Inc ORG
# Bloomberg News ORG
# Thursday DATE
# Goldman PERSON
# fifth ORDINAL
# U.S. GPE
# Elon Musk PERSON
# Tesla PERSON
# Musk PERSON
# Wednesday DATE
# Reuters ORG
# Reuters ORG
# Friday DATE
# New York GPE
# June 1 DATE
# second ORDINAL
# Bitcoin PERSON
# Thursday DATE
# 3,591.65 MONEY
# the Bitstamp Exchange ORG
# about 3.0% PERCENT
# 3,568.92 MONEY
# Bitcoin PERSON
# Friday DATE
# U.S. GPE
# Joe Biden PERSON
# Bitcoin PERSON
# Bitcoin PERSON
# ETH ORG
# Litecoin (LTC ORG
# Bitcoin Cash PERSON
# ATM ORG
# 2019 DATE
# Costa Mesa GPE
# Sean Culkin PERSON
# the Los Angeles Chargers ORG
# the Hoag Performance Center FAC
# Costa Mesa GPE
# California GPE
# Bitcoin PERSON
# January 8, 2021 DATE
# CME Group Inc ORG
# Tuesday DATE
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic PERSON
# Elon Musk's PERSON
# Dogecoin GPE
# Elon Musk PERSON
# a volatile week DATE
# Tesla Inc. ORG
# Musk  PERSON
# Elon Musk PERSON
# Crew Dragon PERSON
# the Kennedy Space Center FAC
# Cape Canave GPE
# 28, 2021 DATE
# Tesla ORG
# Bitcoin PERSON
# the first quarter of 2021 DATE
# the Wall Street Jour ORG
# Entrepreneur ORG
# Mark Cuban PERSON
# Bitcoin PERSON
# Elon Musk PERSON
# 5.63 % PERCENT
# 49,337.72 MONEY
# 0800 CARDINAL
# GMT ORG
# Sunday DATE
# 2,628.83 MONEY
# Bitcoin PERSON
# 77.9% PERCENT
# year DATE
# 27,734 MONEY
# 0.3% PERCENT
# 1.1% PERCENT
# third ORDINAL
# World FX ORG
# TOK ORG
# Santa Clarita GPE
# California GPE
# U.S. GPE
# October 2, 2019 DATE
# Mike BlakeTesla Inc PERSON
# Wednesday DATE
# Tesla PERSON
# Elon Musk PERSON
# Wednesday DATE
# European NORP
# Thursday DATE
# U.S. GPE
# Tesla PERSON
# Elon Musk PERSON
# Wednesday DATE
# Dow Jones Indices ORG
# Sotheby's ORG
# Tuesday DATE
# Banksy PERSON
# Love WORK_OF_ART
# Air LAW
# first ORDINAL
# Dogecoin GPE
# April 20, 2021 DATE
# 1800 CARDINAL
# GMT ORG
# May 19 DATE
# Elon Musk PERSON
# Wednesday DATE
# Tesla Inc PERSON
# 2019 DATE
# Costa Mesa GPE
# Sean Culkin PERSON
# the Los Angeles Chargers ORG
# the Hoag Performance Center FAC
# Costa Mesa GPE
# California GPE
# 200-fold QUANTITY
# the past year DATE
# Elon Musk PERSON
# E3 GPE
# Los Angeles GPE
# California GPE
# U.S. GPE
# June 13, 2019 DATE
# Mike Blake/File Photo/File PhotoElon Musk's PERSON
# New York GPE
# the morning of TIME
# April 17 DATE
# two CARDINAL
# Westchester GPE
# New York GPE
# overnight TIME
# Reuters ORG
# Bitcoin PERSON
# May 20, 2021 DATE
# Reuters ORG
# 65,000 MONEY
# last month DATE
# the United St GPE
# CIO of ARK Investment Management ORG
# Elon Musk PERSON
# Tesla ORG
# Ark Invest PERSON
# File PERSON
# Hannibal Hanschke/ ORG
# AP ORG
# File PERSON
# Sydney GPE
# Australia GPE
# Jonas Liebschner PERSON
# five and a half month DATE
# Bitcoin PERSON
# Marseille GPE
# France GPE
# February 7, 2021 DATE
# Eric GaillardBitcoin's PERSON
# week-long DATE
# $40,000 mark MONEY
# Bitcoin PERSON
# May 19, 2021 DATE
# Dado Ruvic/IllustrationBitcoin PERSON
# 3% PERCENT
# Friday DATE
# LONDON GPE
# Reuters ORG
# 40,000 MONEY
# Thursday DATE
# a day DATE

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_text = ' '.join(eth_df['text'])
eth_text
# Out:
# 'Vitalik Buterin, the creator of Ethereum, on Wednesday donated Ethereum and meme coins worth $1.5 billion in one of the largest-ever individual philanthropy efforts.\r\nButerin transferred 500 ETH and … [+1667 chars] Their investors call them disruptive innovators. Detractors like North Carolina Attorney General Josh Stein call them dirty scammers. But Leda Health co-founders Madison Campbell and Liesel Vaidya th… [+8679 chars] Solana isn’t known yet outside of the crypto community. But insiders think the blockchain platform is interesting for a wide variety of reasons, beginning with its amiable founder, Anatoly Yakovenko,… [+7156 chars] New York (CNN Business)Bitcoin prices continued their rebound Saturday, rising about 6% to nearly $58,000. But the world\'s largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars] The creators behind CryptoPunks, one of the most popular NFT projects on the web, just revealed their latest project called Meebits. The project boasts 20,000 procedurally generated 3D characters tha… [+2000 chars] Bitcoin, Ethereum and a host of Altcoins suffered massive drops Tuesday night and Wednesday morning, erasing months of gains and hundreds of billions in market cap. The overall crypto market shrunk m… [+1182 chars] By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/Illustration\r\nSINGAPORE… [+748 chars] A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether hit a record high of… [+760 chars] It took a while to get here, but Dfinity is finally launching.\xa0\r\nIn July 2018, I went to the Swiss city of Zug to speak to Dominic Williams, CEO of crypto platform Dfinity. Its blockchain project has… [+4319 chars] This story originally appeared on StockMarketUS Stock Futures Edge Higher On Monday Morning\r\nThe U.S. stock futures moved higher in pre-market trading on Monday as investors prepare themselves for th… [+6451 chars] This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nCryptocurrencies are the thing of today. Vitalik Buterin , 27-year-old co-founder of… [+831 chars] A representation of virtual currency Ethereum are seen in front of a stock graph in this illustration taken February 19, 2021. REUTERS/Dado Ruvic/IllustrationCryptocurrency ether extended gains to an… [+632 chars] Posted \r\nThe S&amp;P Dow Jones Indices launched new cryptocurrency indexes, further mainstreaming digital currencies including bitcoin and ethereum by bringing them to the trading floors of Wall Stre… [+30 chars] By Reuters Staff\r\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending last weeks rally in the wake of a report that the Europe… [+444 chars] Sotheby\'s said on Tuesday it would accept bitcoin and ethereum as payment for Banksy\'s iconic artwork "Love is in the Air", a first for a physical art auction and the latest sign of growing mainstrea… [+1176 chars] NEW YORK, May 7 (Reuters) - Ethereum has outperformed major digital currency rivals this year, bolstered by the surge in decentralized finance (DeFi) and the anticipation of a technical adjustment th… [+5345 chars] By Reuters Staff\r\n(Adds detail of reported EIB plan and bitcoin price)\r\nSINGAPORE, May 3 (Reuters) - Cryptocurrency ether hit a record high on Monday to trade within a whisker of $3,000, extending la… [+684 chars] Ethereum has outperformed major digital currency rivals this year, bolstered by the surge in decentralized finance (DeFi) and the anticipation of a technical adjustment this summer, but it faces hurd… [+5218 chars] By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Ethereum are seen in front of a stock graph ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc_eth = nlp(eth_text)
# Add a title to the document
# YOUR CODE HERE!
doc_eth.user_data["title"] = "ETH NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETH NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the creator of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  donated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and meme coins worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  transferred
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and … [+1667 chars] Their investors call them disruptive innovators. Detractors like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Attorney General
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Josh Stein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  call them dirty scammers. But Leda Health co-founders
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Madison Campbell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Liesel Vaidya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  th… [+8679 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Solana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  isn’t known yet outside of the crypto community. But insiders think the blockchain platform is interesting for a wide variety of reasons, beginning with its amiable founder,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anatoly Yakovenko
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,… [+7156 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Business)Bitcoin prices continued their rebound
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , rising
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly $58,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . But the world's largest cryptocurrency has been overshadowed lately by its younger sibling, … [+866 chars] The creators behind
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CryptoPunks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most popular
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  projects on the web, just revealed their latest project called
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meebits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . The project boasts
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; bord

# %%
# List all Entities
# YOUR CODE HERE!
for ent in doc_eth.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Vitalik Buterin PERSON
# Ethereum ORG
# Wednesday DATE
# Ethereum ORG
# $1.5 billion MONEY
# Buterin PERSON
# 500 CARDINAL
# ETH ORG
# North Carolina GPE
# Josh Stein PERSON
# Madison Campbell PERSON
# Liesel Vaidya PERSON
# Solana PERSON
# Anatoly Yakovenko PERSON
# New York GPE
# CNN ORG
# Saturday DATE
# about 6% PERCENT
# nearly $58,000 MONEY
# CryptoPunks ORG
# one CARDINAL
# NFT ORG
# Meebits PRODUCT
# 20,000 CARDINAL
# 3D ORG
# Altcoins PERSON
# Tuesday night TIME
# Wednesday DATE
# morning TIME
# months DATE
# hundreds of billions MONEY
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Dfinity ORG
# July 2018 DATE
# Swiss NORP
# Dominic Williams PERSON
# StockMarketUS Stock Futures Edge Higher ORG
# Monday DATE
# U.S. GPE
# Monday DATE
# Spanish NORP
# AI ORG
# Cryptocurrencies ORG
# today DATE
# Vitalik Buterin PERSON
# 27-year-old DATE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# Dow Jones Indices ORG
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# last weeks DATE
# Europe LOC
# Sotheby's ORG
# Tuesday DATE
# Banksy PERSON
# Love WORK_OF_ART
# Air LAW
# first ORDINAL
# NEW YORK GPE
# May 7 DATE
# Reuters ORG
# this year DATE
# Reuters ORG
# SINGAPORE GPE
# May 3 DATE
# Reuters ORG
# Monday DATE
# 3,000 MONEY
# this year DATE
# this summer DATE
# Reuters ORG
# February 19, 2021 DATE
# SINGAPORE GPE
# 27, 2021 DATE
# Entrepreneur ORG
# this year DATE
# one CARDINAL
# Year after year DATE
# 23, 2021 DATE
# Spanish NORP
# AI ORG
# Bitcoin PERSON
# Friday DATE
# Bitcoin PERSON
# 50,000 MONEY
# first ORDINAL
# early March DATE
# Bitcoin PERSON
# today DATE
# April 14 DATE
# GPU ORG
# Alex Castro PERSON
# The Verge
#
#
#
#  Cryptocurrency ORG
# Coinbase PERSON
# this morning TIME
# Coinbase PERSON
# Bin PERSON
# Bitcoin PERSON
# Ethereum ORG
# Getty Images PERSON
# AsiaPac ORG
# Bitcoin PERSON
# Ethereum ORG
# number two CARDINAL
# 2021 DATE
# February 19, 2021 DATE
# Dado Ruvic/IllustrationBitcoin PERSON
# two CARDINAL
# Bitcoin PERSON
# March 15, 2021 DATE
# Dado Ruvic PERSON
# Dow Jones Indices ORG
# Wednesday DATE
# Spanish NORP
# AI ORG
# Cryptocurrencies ORG
# Ethereum ORG
# above $3,000 MONEY
# Monday DATE
# this year DATE
# Monday DATE
# $3,000 mark MONEY
# Bitcoin ORG
# year-to-date DATE
# Ethereum ORG
# Bitcoin PERSON
# U.S. Dollar ORG
# May 26, 2020 DATE
# Dado Ruvic/File PhotoBitcoin PERSON
# last week DATE
# one-day DATE
# March last year DATE
# Wednesday DATE
# $1 trillion MONEY
# 99.95% PERCENT
# Carl Beekhuizen PERSON
# the Ethereum Foundation ORG
# Beekhuizen ORG
# about one hundred billion trillion dollars MONEY
# Reuters ORG
# May 4 DATE
# Reuters ORG
# Global Inc ORG
# Tuesday DATE
# Reuters ORG
# Ethereum ORG
# above $3,000 MONEY
# Monday DATE
# Reuters ORG
# Bitcoin PERSON
# March 15, 2021 DATE
# Reuters ORG
# Ethereum ORG
# February 19, 2021 DATE
# Dado Ruvic/IllustrationCryptocurrency PERSON
# 4,000 MONEY
# 11 years DATE
# later this year DATE
# Longevica PERSON
# $13 million MONEY
# Reuters ORG
# as much as 5% PERCENT
# Monday DATE
# 3,203 MONEY
# Reuters ORG
# one-day DATE
# two years DATE
# Monday DATE
# second ORDINAL
# 4,000 MONEY
# first ORDINAL
# Ethereum PERSON
# 7% PERCENT
# Spanish NORP
# AI ORG
# This week DATE
# Dow Jones ORG
# Tuesday DATE
# Europe LOC
# 2016 DATE
# Ethereum, Pol ORG
# Last week DATE
# Trump ORG
# This week DATE
# Elon Musk’s ORG
# NFT ORG
# Disaster Girl WORK_OF_ART
# NFT ORG
# over $500,000 MONEY
# Foundation ORG
# Disaster Girl' ORG
# John Phillips PERSON
# 27-year-old DATE
# Ethereum GPE
# Vitalik Buterin PERSON
# 350% PERCENT
# Reuters ORG
# as much as 8.5% PERCENT
# Thursday DATE
# above $2,560 MONEY
# $300 billion MONEY
# first ORDINAL
# Reuters ORG
# April 24 DATE
# Reuters ORG
# 1.77% PERCENT
# 50,269.9 MONEY
# Saturday DATE
# 906.75 MONEY
# Bitcoin PERSON
# 22.5 CARDINAL
# Anthony Di Ionio PERSON
# Ethereum ORG
# Photo PERSON
# Decentral
# Ethereum ORG
# Anthony Di Iorio PERSON
# the kilowatt-hour TIME
# one CARDINAL
# about 12 cents MONEY
# this year DATE
# America GPE
# Mastercard PERSON
# BNY Mellon ORG
# Thursday DATE
# XRP ORG
# Yuriko Nakao PERSON
# Bitcoin PERSON
# 47,000 MONEY
# 26, 2021 DATE
# this year DATE
# Bitcoin, Ethereum ORG
# Dogecoin GPE
# Coinba PERSON
# April 28 DATE
# Reuters ORG
# The European Investment Bank ORG
# 100 million CARDINAL
# $121 million MONEY
# two-year DATE
# Reuters ORG
# Millions of dollars MONEY
# NurPhoto ORG
# Getty Images
# Cryptocurrency ORG
# Wednesday DATE
# New York GPE
# the morning of TIME
# April 17 DATE
# two CARDINAL
# Westchester GPE
# New York GPE
# overnight TIME
# the past few days DATE
# Vitalik Buterin PERSON
# Bitcoin PERSON
# April 24, 2020 DATE
# 1.77% PERCENT
# Bitcoin PERSON
# Marseille GPE
# France GPE
# February 7, 2021 DATE
# Eric GaillardBitcoin PERSON
# 6.54% PERCENT
# 57,098.08 MONEY
# Friday DATE
# 3,504.11 MONEY
# Bitcoin PERSON
# U.S. Dollar ORG
# May 26, 2020 DATE
# 6.8% PERCENT
# $56,852.03 MONEY
# 1000 CARDINAL
# GMT ORG
# Wednesday DATE
# 5.63 % PERCENT
# 49,337.72 MONEY
# 0800 CARDINAL
# GMT ORG
# Sunday DATE
# 2,628.83 MONEY
# Bitcoin PERSON
# 77.9% PERCENT
# year DATE
# 27,734 MONEY
# LHR ORG
# 18 CARDINAL
# 18 CARDINAL
# Nvidia PERSON
# GeForce ORG
# 3000 CARDINAL
# nine-week DATE
# Thursday DATE
# U.S. Treasury ORG
# the first quarter DATE
# NurPhoto ORG
# Getty Images ORG
# The Chicago Board Options Exchange ORG
# the US Securities and Exchange Commission ORG
# Monday DATE
# Fidelity ORG
# 27, 2021 DATE
# Entrepreneur ORG
# Bitcoin PERSON
# over 9% PERCENT
# 50,000 MONEY
# CoinDesk ORG
# Monday DATE
# recent years DATE
# the first four months of the year DATE
# Framework Ventures ORG
# Friday DATE
# $100 million MONEY
# second ORDINAL
# Bitcoin PERSON
# weekly DATE
# CoinShares ORG
# Bitcoin PERSON
# as much as 8% PERCENT
# Monday DATE
# five straight days DATE
# almost a fifth CARDINAL
# earlier this month DATE
# Bit PERSON
# a bad week DATE
# Elon Musk PERSON
# Bitcoins PERSON
# 12k MONEY
# Tesla ORG
# Bitcoin PERSON
# Elon Musk PERSON
# Bitcoin PERSON
# Bitcoin PERSON
# about 20% PERCENT
# a few hours TIME
# about 12% PERCENT
# CNN Business ORG
# Julia Horowitz PERSON
# John Phillips PERSON
# Vitalik Buterin PERSON
# 90% PERCENT
# Shiba Inu ORG
# 10% PERCENT
# Sund ORG
# Wednesday DATE
# thousands CARDINAL
# a rough day DATE
# Wednesday DATE
# 10 CARDINAL
# Things Before the Opening Bell WORK_OF_ART
# Wednesday DATE
# thousands CARDINAL
# Vitalik Buterin PERSON
# 90% PERCENT
# Shiba Inu ORG
# 10% PERCENT
# Sunday DATE
# evening TIME
# Over 40% PERCENT
# Meet Finary ORG
# French NORP
# Mike Novogratz PERSON
# Lucas Jackson PERSON
# Reuters ORG
# Billionaire PERSON
# Mike Novogratz PERSON
# between $40,00… MONEY
# Entrepreneur ORG
# a manic Monday DATE
# half a trillion dollars MONEY
# Bitcoin PERSON
# Earlier this year DATE
# Nvidia ORG
# GeForce ORG
# 3060 DATE
# Kitco News ORG
# 30,000 MONEY
# first ORDINAL
# late January DATE
# Bitcoin PERSON
# three-month DATE
# Monday DATE
# Elon Musk's PERSON
# the weekend DATE
# Stanley Druckenmiller PERSON
# REUTERS ORG
# Brendan McDermid
#  ORG
# >Stanley Druckenmiller PERSON
# the Federal Reserve ORG
# Elon Musk PERSON
# Ringo H.W. Chiu PERSON
# Elon Musk PERSON
# Wednesday night TIME
# Reuters ORG
# SINGAPORE PERSON
# Reuters ORG
# three-month DATE
# Monday DATE
# Elon Musks PERSON
# the weekend DATE
# 2015 DATE
# David Grider PERSON
# first ORDINAL
# Mark Cuban PERSON
# Brian Snyder PERSON
# Reuters ORG
# Mark Cuban PERSON
# $1 million MONEY
# Netflix ORG
# Amazon ORG
# $1 million MONEY
# Chris Larsen PERSON
# YouTube ORG
# Chris Larsen PERSON
# Ripp PERSON
# Wednesday DATE
# China GPE
# Tesla ORG
# $40,000 mark MONEY
# Wednesday DATE
# three CARDINAL
# China GPE
# Sydney GPE
# Australia GPE
# Jonas Liebschner PERSON
# five and a half month DATE
# Thursday DATE
# Bank of England ORG
# Andrew Bailey PERSON
# CNBC ORG
# Spanish NORP
# AI ORG
# Bitcoin, Ethereum ORG

# %% [markdown]
# ---
